# %% [markdown]
# # OpenRouter LLM annotacija članaka
#
# Ova verzija je očišćena od Ollama koda i koristi samo OpenRouter API.
#
# Šta notebook radi:
# 1. učita CSV dataset,
# 2. pošalje članke na OpenRouter model,
# 3. traži striktan JSON output,
# 4. validira JSON,
# 5. snimi raw rezultate, flat CSV i agreement summary.
#
# Napomena: kolona `tema` u datasetu je samo početna/sampling klasa i ne šalje se modelu u prompt, da ne bi biasirala anotaciju.

# %%
# 1) OPENROUTER API KEY
# Opcija A: pokreni ćeliju i unesi key kada te pita.
# Opcija B: otkomentariši liniju ispod i ručno upiši key, ali to nije preporučeno ako dijeliš notebook.
# os.environ["OPENROUTER_API_KEY"] = "sk-or-v1-..."

import os
from getpass import getpass

OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY", "").strip()

if not OPENROUTER_API_KEY:
    OPENROUTER_API_KEY = getpass("Unesi OPENROUTER_API_KEY: ").strip()
    os.environ["OPENROUTER_API_KEY"] = OPENROUTER_API_KEY

if not OPENROUTER_API_KEY:
    raise RuntimeError("OPENROUTER_API_KEY nije postavljen.")

print("OPENROUTER_API_KEY je postavljen.")
# Out:
# Unesi OPENROUTER_API_KEY:  ········
# OPENROUTER_API_KEY je postavljen.

# %%
# 2) IMPORTI

import json
import os
import re
import time
from pathlib import Path

import pandas as pd
import requests

# %%
# 3) KONFIGURACIJA

OPENROUTER_URL = "https://openrouter.ai/api/v1/chat/completions"

# Model ID na OpenRouteru.
# Možeš promijeniti npr. u "qwen/qwen3.6-max-preview" ako želiš jači model.
MODEL = "qwen/qwen3.6-35b-a3b"

# Ako je None, notebook pokušava automatski pronaći CSV u trenutnom folderu, /content ili /mnt/data.
# Ako radiš u Colabu, uploaduj CSV u Files panel i ostavi None ili upiši tačan path.
INPUT_CSV = None

OUTPUT_DIR = "openrouter_prompt_tests"

# Za test ostavi 5/10/50. Za cijeli dataset stavi None.
N_ROWS = None

# Tri prompta po članku = len(df) * 3 API poziva.
PROMPT_NAMES_TO_RUN = [
    "prompt_1_basic",
    "prompt_2_evidence_first",
    "prompt_3_conservative",
]

SLEEP_BETWEEN = 0.2
MAX_RETRIES = 3
RETRY_BACKOFF = 5

# Ako se batch prekine, ponovni run preskače već obrađene (article_id, prompt_name).
RESUME = True

# Kod Qwen reasoning modela ovo smanjuje trošak i šansu da model vrati <think>.
# Ako OpenRouter/provider ne prihvati ovaj parametar, kod automatski ponovi request bez njega.
DISABLE_REASONING = True

GENERATION_OPTIONS = {
    "temperature": 0,
    "top_p": 0.9,
    "max_tokens": 2000,
}

TOPIC_KEYS = [
    "euroatlantske_integracije",
    "negiranje_genocida",
    "gradjanska_vs_konstitutivni",
    "izborna_reforma",
]

# %%
# 4) UČITAVANJE DATASETA

def find_input_csv(input_csv=None):
    """
    Traži dataset na nekoliko čestih lokacija.
    Ovo pomaže jer se ime može razlikovati: example_sampled_llm_500.csv ili example_sampled_llm_500(1).csv.
    """
    candidates = []

    if input_csv:
        candidates.append(Path(input_csv))

    names = [
        "example_sampled_llm_500.csv",
        "example_sampled_llm_500(1).csv",
        "ex_sampling_llm_500.csv",
    ]

    base_dirs = [
        Path.cwd(),
        Path("/content"),
        Path("/mnt/data"),
    ]

    for base in base_dirs:
        for name in names:
            candidates.append(base / name)

    for path in candidates:
        if path.exists():
            return path

    raise FileNotFoundError(
        "Ne mogu pronaći CSV. Postavi INPUT_CSV na tačan path, npr. "
        'INPUT_CSV = "/content/example_sampled_llm_500.csv"'
    )


input_path = find_input_csv(INPUT_CSV)
df = pd.read_csv(input_path, dtype={"article_id": str})

required_columns = ["PORTAL", "DATUM", "NASLOV", "SADRZAJ", "article_id"]
missing = [col for col in required_columns if col not in df.columns]
if missing:
    raise ValueError(f"Nedostaju obavezne kolone u CSV-u: {missing}")

df["SADRZAJ"] = df["SADRZAJ"].fillna("")

if "article_id" not in df.columns:
    df["article_id"] = range(len(df))
df["article_id"] = df["article_id"].astype(str)

print("CSV:", input_path)
print("Shape:", df.shape)
display(df.head(3))
print("\nNaN po kolonama:")
display(df.isna().sum().sort_values(ascending=False).head(15))
# Out:
# CSV: D:\DSAI\Fourth Semester\CDA\Project\example_sampled_llm_500.csv
# Shape: (500, 9)
#   PORTAL       DATUM                                             NASLOV  \
# 0   RTRS  2020-03-07  Državljanin Srbije među zaraženim članovima po...
# 1   RTRS  2021-11-13  "Vašington upozoren da ne podržava nezavisnost...
# 2   RTRS  2024-10-21  Moldavci podijeljeni na referendumu o učlanjen...
#
#                                              SADRZAJ  \
# 0  Od evropskih zemalja, najteže je pogođena Ital...
# 1  Vang je naglasio da Vašington treba da ispuni ...
# 2  Broj ljudi koji su na referendumu u Moldaviji ...
#
#                           tema article_id period_start period_start.1  \
# 0    euroatlantske_integracije     124893   2020-03-02     2020-03-02
# 1  gradjanska_vs_konstitutivni     182281   2021-11-07     2021-11-07
# 2              izborna_reforma     152466   2024-10-07     2024-10-07
#
#    period_end
# 0  2020-03-16
# 1  2021-11-21
# 2  2024-10-21
# NaN po kolonama:
# PORTAL            0
# DATUM             0
# NASLOV            0
# SADRZAJ           0
# tema              0
# article_id        0
# period_start      0
# period_start.1    0
# period_end        0
# dtype: int64

# %%
# 5) PROMPTI
# Bitno: ne koristimo Python .format() jer JSON schema sadrži obične { } zagrade.
# Umjesto toga koristimo sigurnu zamjenu placeholdera tipa <<ARTICLE_ID>>.

PROMPT_1 = """
Ti si politički annotator za članke iz Bosne i Hercegovine.

Zadatak: Analiziraj dati novinski članak i označi da li se suštinski odnosi na jednu ili više od ove četiri političke teme:

1. euroatlantske_integracije
2. negiranje_genocida
3. gradjanska_vs_konstitutivni
4. izborna_reforma

Vrlo važno:
- Tema je "mentioned": true samo ako je tema suštinski prisutna u članku.
- Nemoj označiti temu kao prisutnu ako se pojavljuje samo usputna riječ.
- Ako nema dovoljno dokaza, koristi mentioned=false.
- Ako je članak samo neutralna vijest bez jasnog vrijednosnog stava, stance=0.
- Vrati isključivo validan JSON. Bez markdowna, bez komentara.

Definicije stance:

euroatlantske_integracije:
1 = podržava EU/NATO integracije
0 = neutralno, miješano ili nejasno
-1 = protivi se EU/NATO integracijama

negiranje_genocida:
1 = osuđuje negiranje genocida ili priznaje genocid/presude
0 = neutralno izvještava
-1 = negira, minimizira ili relativizira genocid

gradjanska_vs_konstitutivni:
1 = podržava građanski model države
0 = neutralno, miješano ili nejasno
-1 = podržava princip konstitutivnih naroda / legitimno predstavljanje / etničko predstavljanje

izborna_reforma:
1 = podržava izbornu reformu ili spomenuti prijedlog reforme
0 = neutralno, miješano ili nejasno
-1 = protivi se izbornoj reformi ili kritikuje spomenuti prijedlog reforme

Output schema:
{
  "article_id": "<<ARTICLE_ID>>",
  "is_relevant": true,
  "primary_topic": "euroatlantske_integracije | negiranje_genocida | gradjanska_vs_konstitutivni | izborna_reforma | none",
  "topics": {
    "euroatlantske_integracije": {
      "mentioned": true,
      "stance": 1,
      "confidence": 0.86,
      "evidence": []
    },
    "negiranje_genocida": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.95,
      "evidence": []
    },
    "gradjanska_vs_konstitutivni": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.95,
      "evidence": []
    },
    "izborna_reforma": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.95,
      "evidence": []
    }
  }
}

Članak:
article_id: <<ARTICLE_ID>>
portal: <<PORTAL>>
datum: <<DATUM>>
naslov: <<NASLOV>>
sadrzaj:
<<SADRZAJ>>
"""


PROMPT_2 = """
Ti si strogi annotator političkih tema u novinskim člancima iz Bosne i Hercegovine.

Analiziraj članak i označi samo teme za koje postoji jasan tekstualni dokaz.

Pravila:
- Ne zaključuj na osnovu portala, autora ili političkih aktera ako tema nije stvarno prisutna u tekstu.
- Ne koristi svoje vanjsko znanje.
- Ne označavaj temu samo zato što se spominje političar.
- Za svaku temu koja je mentioned=true, moraš navesti 1 do 3 kratka evidence citata ili fraze iz članka.
- Ako nema citata/fraze koja podržava oznaku, mentioned mora biti false.
- Vrati samo JSON.

Teme i stance:

1. euroatlantske_integracije
Relevantno ako članak govori o EU, NATO, kandidatskom statusu, evropskom putu, MAP/ANP, integracijama, sankcijama ili geopolitici direktno vezanoj za EU/NATO put BiH.
stance:
1 = pro EU/NATO
0 = neutralno/miješano/nejasno
-1 = anti EU/NATO

2. negiranje_genocida
Relevantno ako članak govori o genocidu u Srebrenici, negiranju/minimiziranju genocida, presudama, ratnim zločincima, Inzkovom zakonu ili zabrani negiranja.
stance:
1 = priznaje/štiti istinu o genocidu ili osuđuje negiranje
0 = neutralno izvještava
-1 = negira/minimizira/relativizira genocid

3. gradjanska_vs_konstitutivni
Relevantno ako članak govori o građanskoj državi, konstitutivnim narodima, legitimnom predstavljanju, majorizaciji, etničkom predstavljanju, Domu naroda, ustavnoj strukturi BiH.
stance:
1 = pro građanski model
0 = neutralno/miješano/nejasno
-1 = pro konstitutivni narodi / legitimno predstavljanje

4. izborna_reforma
Relevantno ako članak govori o izmjenama Izbornog zakona, CIK-u, tehničkim izmjenama izbora, Schmidtovim/OHR izmjenama, pregovorima SDA-HDZ-DF, Ljubić presudi, Domu naroda u kontekstu izbora.
stance:
1 = podržava reformu/prijedlog
0 = neutralno/miješano/nejasno
-1 = protivi se reformi/prijedlogu

JSON mora imati tačno ovaj oblik:
{
  "article_id": "<<ARTICLE_ID>>",
  "is_relevant": false,
  "primary_topic": "none",
  "topics": {
    "euroatlantske_integracije": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    },
    "negiranje_genocida": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    },
    "gradjanska_vs_konstitutivni": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    },
    "izborna_reforma": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    }
  }
}

Sada popuni JSON za članak:

ID:
<<ARTICLE_ID>>

NASLOV:
<<NASLOV>>

SADRŽAJ:
<<SADRZAJ>>
"""


PROMPT_3 = """
Ti si annotator za dataset novinskih članaka. Tvoj glavni cilj je visoka preciznost, ne visoki recall.

To znači:
- Bolje je propustiti slab ili nejasan slučaj nego pogrešno označiti članak kao relevantan.
- Ako članak ne govori suštinski o jednoj od četiri teme, is_relevant mora biti false.
- Pojedinačna riječ nije dovoljna za relevantnost.
- Spominjanje EU države, izbora u drugoj državi, policije, zdravstva, kriminala ili lokalnih događaja nije relevantno osim ako je direktno povezano sa jednom od četiri definisane teme u BiH.

Teme:
- euroatlantske_integracije: EU/NATO put BiH, evropske integracije, NATO, MAP/ANP, kandidatski status, reforme za EU/NATO.
- negiranje_genocida: Srebrenica, genocid, negiranje/minimiziranje, presude, ratni zločinci, zabrana negiranja.
- gradjanska_vs_konstitutivni: građanska država, konstitutivni narodi, legitimno predstavljanje, majorizacija, etnički veto, Dom naroda.
- izborna_reforma: Izborni zakon BiH, izborna reforma, CIK, OHR/Schmidt izmjene, Ljubić, tehnički integritet izbora.

Stance:
- Za euroatlantske_integracije: 1 pro EU/NATO, -1 anti EU/NATO, 0 neutralno/nejasno.
- Za negiranje_genocida: 1 protiv negiranja/priznaje genocid, -1 negira/relativizira, 0 neutralno/nejasno.
- Za gradjanska_vs_konstitutivni: 1 pro građanski model, -1 pro konstitutivni narodi/legitimno predstavljanje, 0 neutralno/nejasno.
- Za izborna_reforma: 1 podržava spomenutu reformu, -1 protivi se spomenutoj reformi, 0 neutralno/nejasno.

Vrati samo validan JSON. Ne dodaji objašnjenje.

JSON schema:
{
  "article_id": "<<ARTICLE_ID>>",
  "is_relevant": false,
  "primary_topic": "none",
  "topics": {
    "euroatlantske_integracije": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    },
    "negiranje_genocida": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    },
    "gradjanska_vs_konstitutivni": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    },
    "izborna_reforma": {
      "mentioned": false,
      "stance": 0,
      "confidence": 0.0,
      "evidence": []
    }
  }
}

Članak:
ID: <<ARTICLE_ID>>
Naslov: <<NASLOV>>
Sadržaj:
<<SADRZAJ>>
"""


PROMPTS = {
    "prompt_1_basic": PROMPT_1,
    "prompt_2_evidence_first": PROMPT_2,
    "prompt_3_conservative": PROMPT_3,
}

# %%
# 6) HELPERI ZA TEKST I PROMPT

def clean_text(x):
    if pd.isna(x):
        return ""
    return str(x).strip()


def truncate_text(text, max_chars=12000):
    """
    Ako je članak predug, šaljemo samo početak teksta.
    Kod vijesti su najvažnije informacije najčešće na početku.
    """
    text = clean_text(text)
    if len(text) <= max_chars:
        return text
    return text[:max_chars] + "\n\n[TEKST SKRAĆEN ZBOG DUŽINE]"


def render_prompt(template, row):
    """
    Sigurnija zamjena od .format(), jer prompt sadrži JSON zagrade { }.
    """
    replacements = {
        "<<ARTICLE_ID>>": clean_text(row.get("article_id", "")),
        "<<PORTAL>>": clean_text(row.get("PORTAL", "")),
        "<<DATUM>>": clean_text(row.get("DATUM", "")),
        "<<NASLOV>>": clean_text(row.get("NASLOV", "")),
        "<<SADRZAJ>>": truncate_text(row.get("SADRZAJ", "")),
    }

    prompt = template
    for key, value in replacements.items():
        prompt = prompt.replace(key, value)

    return prompt


# Brzi sanity check da prompt render ne puca zbog JSON zagrada.
_test_prompt = render_prompt(PROMPTS["prompt_3_conservative"], df.iloc[0])
print(_test_prompt[:800])
# Out:
# Ti si annotator za dataset novinskih članaka. Tvoj glavni cilj je visoka preciznost, ne visoki recall.
#
# To znači:
# - Bolje je propustiti slab ili nejasan slučaj nego pogrešno označiti članak kao relevantan.
# - Ako članak ne govori suštinski o jednoj od četiri teme, is_relevant mora biti false.
# - Pojedinačna riječ nije dovoljna za relevantnost.
# - Spominjanje EU države, izbora u drugoj državi, policije, zdravstva, kriminala ili lokalnih događaja nije relevantno osim ako je direktno povezano sa jednom od četiri definisane teme u BiH.
#
# Teme:
# - euroatlantske_integracije: EU/NATO put BiH, evropske integracije, NATO, MAP/ANP, kandidatski status, reforme za EU/NATO.
# - negiranje_genocida: Srebrenica, genocid, negiranje/minimiziranje, presude, ratni zločinci, zabrana negiranja.
# - gradjanska_vs_konsti

# %%
# 7) OPENROUTER POZIV

def call_openrouter(prompt, response_format=True, disable_reasoning=DISABLE_REASONING):
    """
    Poziva OpenRouter Chat Completions endpoint.
    Ako provider odbije reasoning ili response_format parametar, kod proba fallback.
    """

    api_key = os.environ.get("OPENROUTER_API_KEY", "").strip()
    if not api_key:
        raise RuntimeError("OPENROUTER_API_KEY nije postavljen.")

    payload = {
        "model": MODEL,
        "messages": [
            {
                "role": "system",
                "content": (
                    "Ti si strogi annotator. Vrati samo validan JSON koji odgovara traženoj shemi. "
                    "Ne piši markdown, objašnjenja, niti dodatni tekst."
                ),
            },
            {"role": "user", "content": prompt},
        ],
        **GENERATION_OPTIONS,
    }

    if response_format:
        payload["response_format"] = {"type": "json_object"}

    if disable_reasoning:
        payload["reasoning"] = {"effort": "none", "exclude": True}

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
        "HTTP-Referer": "https://localhost",
        "X-Title": "bih-politicke-teme-annotacija",
    }

    last_error = None

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = requests.post(
                OPENROUTER_URL,
                headers=headers,
                json=payload,
                timeout=120,
            )

            # Ako neki provider ne prihvati reasoning parametar, probaj bez njega.
            if response.status_code in {400, 422} and "reasoning" in payload:
                payload = dict(payload)
                payload.pop("reasoning", None)
                print("  Provider nije prihvatio reasoning parametar; ponavljam bez reasoning parametra.")
                continue

            # Ako neki provider ne prihvati response_format, probaj bez njega.
            if response.status_code in {400, 422} and "response_format" in payload:
                payload = dict(payload)
                payload.pop("response_format", None)
                print("  Provider nije prihvatio response_format; ponavljam bez response_format.")
                continue

            if response.status_code == 429:
                wait = RETRY_BACKOFF * attempt
                print(f"  Rate limit 429; čekam {wait}s...")
                time.sleep(wait)
                continue

            response.raise_for_status()
            data = response.json()

            message = data["choices"][0]["message"]
            content = message.get("content", "")

            if not content:
                raise RuntimeError(f"OpenRouter response nema content. Full response: {data}")

            return content

        except requests.exceptions.RequestException as e:
            last_error = e
            wait = RETRY_BACKOFF * attempt
            print(f"  Request greška: {e}; pokušaj {attempt}/{MAX_RETRIES}; čekam {wait}s...")
            time.sleep(wait)

    raise RuntimeError(f"Svi pokušaji su pali. Posljednja greška: {last_error}")

# %%
# 8) JSON PARSIRANJE I VALIDACIJA

def extract_json(text):
    """
    Sa response_format=json_object model bi trebao vratiti čist JSON.
    Fallback: izvlačimo prvi JSON objekat iz teksta.
    """
    text = clean_text(text)

    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass

    match = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if not match:
        raise ValueError("Nije pronađen JSON objekat u odgovoru modela.")

    return json.loads(match.group(0))


def validate_annotation(obj):
    errors = []

    if not isinstance(obj, dict):
        return False, ["Output nije dict."]

    if "article_id" not in obj:
        errors.append("Nedostaje article_id.")

    if "is_relevant" not in obj or not isinstance(obj["is_relevant"], bool):
        errors.append("Nedostaje ili je neispravan is_relevant.")

    allowed_primary = TOPIC_KEYS + ["none"]
    if obj.get("primary_topic") not in allowed_primary:
        errors.append(f"Neispravan primary_topic: {obj.get('primary_topic')}")

    topics = obj.get("topics")
    if not isinstance(topics, dict):
        errors.append("Nedostaje ili je neispravan topics.")
        return False, errors

    for topic in TOPIC_KEYS:
        if topic not in topics:
            errors.append(f"Nedostaje topic: {topic}")
            continue

        item = topics[topic]

        if not isinstance(item, dict):
            errors.append(f"{topic} nije dict.")
            continue

        if "mentioned" not in item or not isinstance(item["mentioned"], bool):
            errors.append(f"{topic}.mentioned nije bool.")

        if item.get("stance") not in [-1, 0, 1]:
            errors.append(f"{topic}.stance nije -1/0/1: {item.get('stance')}")

        conf = item.get("confidence")
        if not isinstance(conf, (int, float)) or not (0 <= conf <= 1):
            errors.append(f"{topic}.confidence nije u [0, 1]: {conf}")

        if "evidence" not in item or not isinstance(item["evidence"], list):
            errors.append(f"{topic}.evidence nije lista.")

        if item.get("mentioned") is False and item.get("stance", 0) != 0:
            errors.append(f"{topic}: mentioned=false, ali stance nije 0.")

        if item.get("mentioned") is True and item.get("confidence", 0) == 0:
            errors.append(f"{topic}: mentioned=true, ali confidence=0.")

    return len(errors) == 0, errors


def flatten_result(article_id, prompt_name, parsed, valid, errors, raw_response, source_row=None):
    source_row = source_row if source_row is not None else {}

    row = {
        "article_id": article_id,
        "prompt_name": prompt_name,
        "valid_json": bool(valid),
        "error": "; ".join(errors) if isinstance(errors, list) else str(errors),
        "raw_response": raw_response,
        "portal": clean_text(source_row.get("PORTAL", "")) if hasattr(source_row, "get") else "",
        "datum": clean_text(source_row.get("DATUM", "")) if hasattr(source_row, "get") else "",
        "naslov": clean_text(source_row.get("NASLOV", "")) if hasattr(source_row, "get") else "",
        "tema_sampling": clean_text(source_row.get("tema", "")) if hasattr(source_row, "get") else "",
    }

    if isinstance(parsed, dict):
        row["is_relevant"] = parsed.get("is_relevant")
        row["primary_topic"] = parsed.get("primary_topic")
        topics = parsed.get("topics", {})
    else:
        row["is_relevant"] = None
        row["primary_topic"] = None
        topics = {}

    # Uvijek napravi sve kolone, čak i ako parsing padne.
    for topic in TOPIC_KEYS:
        item = topics.get(topic, {}) if isinstance(topics, dict) else {}
        row[f"{topic}_mentioned"] = item.get("mentioned")
        row[f"{topic}_stance"] = item.get("stance")
        row[f"{topic}_confidence"] = item.get("confidence")
        row[f"{topic}_evidence"] = json.dumps(item.get("evidence", []), ensure_ascii=False)

    return row

# %%
# 9) TEST NA JEDNOM ČLANKU
# Pokreni ovo prije cijelog batcha da provjeriš da API key, model i JSON parsing rade.

def test_one_article(row_idx=0, prompt_name="prompt_3_conservative"):
    row = df.iloc[row_idx]
    prompt = render_prompt(PROMPTS[prompt_name], row)

    raw_response = call_openrouter(prompt)
    parsed = extract_json(raw_response)
    valid, errors = validate_annotation(parsed)

    print("VALID:", valid)
    print("ERRORS:", errors)
    print(json.dumps(parsed, ensure_ascii=False, indent=2))

    return parsed


# Odkomentariši za test:
# test_result = test_one_article(row_idx=0, prompt_name="prompt_3_conservative")

# %%
# 10) AGREEMENT I FINAL LABEL HELPERS

def _mode_or_none(series):
    values = [x for x in series.dropna().tolist() if x != ""]
    if not values:
        return None
    counts = pd.Series(values).value_counts()
    return counts.index[0]


def agreement_summary(flat_df):
    """
    Poredi promptove po article_id.
    Korisno da vidiš gdje se promptovi ne slažu.
    """
    if flat_df.empty:
        return pd.DataFrame()

    rows = []

    for article_id, g in flat_df.groupby("article_id"):
        item = {"article_id": article_id}

        for meta_col in ["portal", "datum", "naslov", "tema_sampling"]:
            if meta_col in g.columns:
                item[meta_col] = _mode_or_none(g[meta_col])

        rel_values = g["is_relevant"].dropna().astype(str).unique().tolist()
        item["is_relevant_values"] = "|".join(rel_values)
        item["is_relevant_agree"] = len(rel_values) == 1

        primary_values = g["primary_topic"].dropna().astype(str).unique().tolist()
        item["primary_topic_values"] = "|".join(primary_values)
        item["primary_topic_agree"] = len(primary_values) == 1

        for topic in TOPIC_KEYS:
            mentioned_values = g[f"{topic}_mentioned"].dropna().astype(str).unique().tolist()
            stance_values = g[f"{topic}_stance"].dropna().astype(str).unique().tolist()

            item[f"{topic}_mentioned_values"] = "|".join(mentioned_values)
            item[f"{topic}_mentioned_agree"] = len(mentioned_values) == 1

            item[f"{topic}_stance_values"] = "|".join(stance_values)
            item[f"{topic}_stance_agree"] = len(stance_values) == 1

        rows.append(item)

    return pd.DataFrame(rows)


def make_final_majority_labels(flat_df):
    """
    Jednostavna agregacija preko promptova:
    - za is_relevant i primary_topic uzima najčešću vrijednost,
    - za svaku temu uzima većinsku mentioned/stance vrijednost,
    - confidence je prosjek validnih confidence vrijednosti.
    """
    if flat_df.empty:
        return pd.DataFrame()

    rows = []

    for article_id, g in flat_df.groupby("article_id"):
        item = {"article_id": article_id}

        for meta_col in ["portal", "datum", "naslov", "tema_sampling"]:
            if meta_col in g.columns:
                item[meta_col] = _mode_or_none(g[meta_col])

        item["is_relevant_final"] = _mode_or_none(g["is_relevant"].astype("object"))
        item["primary_topic_final"] = _mode_or_none(g["primary_topic"].astype("object"))
        item["n_prompts"] = len(g)
        item["n_valid_json"] = int(g["valid_json"].sum())

        for topic in TOPIC_KEYS:
            mentioned_col = f"{topic}_mentioned"
            stance_col = f"{topic}_stance"
            confidence_col = f"{topic}_confidence"

            item[f"{topic}_mentioned_final"] = _mode_or_none(g[mentioned_col].astype("object"))
            item[f"{topic}_stance_final"] = _mode_or_none(g[stance_col].astype("object"))
            item[f"{topic}_confidence_mean"] = pd.to_numeric(g[confidence_col], errors="coerce").mean()

        rows.append(item)

    return pd.DataFrame(rows)

# %%
# 11) BATCH RUN

def read_existing_jsonl(path):
    records = []
    if not path.exists():
        return records

    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                records.append(json.loads(line))
            except json.JSONDecodeError:
                continue

    return records


def run_batch():
    output_dir = Path(OUTPUT_DIR)
    output_dir.mkdir(parents=True, exist_ok=True)

    run_df = df.copy()
    if N_ROWS is not None:
        run_df = run_df.head(N_ROWS).copy()

    selected_prompts = {name: PROMPTS[name] for name in PROMPT_NAMES_TO_RUN}

    raw_jsonl_path = output_dir / "raw_prompt_outputs.jsonl"
    existing_records = read_existing_jsonl(raw_jsonl_path) if RESUME else []
    done_pairs = {
        (str(r.get("article_id")), str(r.get("prompt_name")))
        for r in existing_records
        if r.get("article_id") is not None and r.get("prompt_name") is not None
    }

    total_calls = len(run_df) * len(selected_prompts)
    skipped = 0
    new_calls = 0

    with open(raw_jsonl_path, "a", encoding="utf-8") as f_jsonl:
        call_idx = 0

        for _, row in run_df.iterrows():
            article_id = clean_text(row["article_id"])

            for prompt_name, template in selected_prompts.items():
                call_idx += 1
                pair = (article_id, prompt_name)

                if RESUME and pair in done_pairs:
                    skipped += 1
                    print(f"[{call_idx}/{total_calls}] SKIP article_id={article_id} | {prompt_name}")
                    continue

                new_calls += 1
                print(f"[{call_idx}/{total_calls}] article_id={article_id} | {prompt_name}")

                prompt = render_prompt(template, row)

                raw_response = ""
                parsed = None
                valid = False
                errors = []

                try:
                    raw_response = call_openrouter(prompt)
                    parsed = extract_json(raw_response)
                    valid, errors = validate_annotation(parsed)
                except Exception as e:
                    errors = [str(e)]

                record = {
                    "article_id": article_id,
                    "prompt_name": prompt_name,
                    "valid_json": valid,
                    "errors": errors,
                    "parsed": parsed,
                    "raw_response": raw_response,
                }

                f_jsonl.write(json.dumps(record, ensure_ascii=False) + "\n")
                f_jsonl.flush()

                time.sleep(SLEEP_BETWEEN)

    print(f"\nBatch završen. Novi pozivi: {new_calls}, preskočeno zbog RESUME: {skipped}")
    print("Raw JSONL:", raw_jsonl_path)

    return build_output_tables(raw_jsonl_path, run_df, output_dir)


def build_output_tables(raw_jsonl_path, source_df, output_dir):
    records = read_existing_jsonl(raw_jsonl_path)

    source_by_id = {
        clean_text(row["article_id"]): row
        for _, row in source_df.iterrows()
    }

    flat_rows = []
    for record in records:
        article_id = clean_text(record.get("article_id", ""))
        source_row = source_by_id.get(article_id, {})

        flat_rows.append(
            flatten_result(
                article_id=article_id,
                prompt_name=record.get("prompt_name", ""),
                parsed=record.get("parsed"),
                valid=record.get("valid_json", False),
                errors=record.get("errors", []),
                raw_response=record.get("raw_response", ""),
                source_row=source_row,
            )
        )

    flat_df = pd.DataFrame(flat_rows)

    flat_csv_path = output_dir / "flat_prompt_results.csv"
    flat_df.to_csv(flat_csv_path, index=False, encoding="utf-8-sig")

    summary_df = agreement_summary(flat_df)
    summary_csv_path = output_dir / "prompt_agreement_summary.csv"
    summary_df.to_csv(summary_csv_path, index=False, encoding="utf-8-sig")

    final_df = make_final_majority_labels(flat_df)
    final_csv_path = output_dir / "final_majority_labels.csv"
    final_df.to_csv(final_csv_path, index=False, encoding="utf-8-sig")

    print("\nOutput fajlovi:")
    print("Flat CSV:", flat_csv_path)
    print("Agreement summary CSV:", summary_csv_path)
    print("Final majority labels CSV:", final_csv_path)

    if len(flat_df):
        print("\nValid JSON po promptu:")
        display(flat_df.groupby("prompt_name")["valid_json"].mean())

        print("\nRelevant count po promptu:")
        display(flat_df.groupby("prompt_name")["is_relevant"].sum())

    return flat_df, summary_df, final_df

# %%
# 12) POKRETANJE CIJELOG BATCHA

# Za prvi test preporuka:
# 1) ostavi N_ROWS = 10
# 2) pokreni ovu ćeliju
# 3) ako je sve uredu, vrati se gore i stavi N_ROWS = None za cijeli dataset

flat_df, summary_df, final_df = run_batch()

display(flat_df.head())
display(summary_df.head())
display(final_df.head())
# Out:
# [1/1500] article_id=124893 | prompt_1_basic
# [2/1500] article_id=124893 | prompt_2_evidence_first
# [3/1500] article_id=124893 | prompt_3_conservative
# [4/1500] article_id=182281 | prompt_1_basic
# [5/1500] article_id=182281 | prompt_2_evidence_first
# [6/1500] article_id=182281 | prompt_3_conservative
# [7/1500] article_id=152466 | prompt_1_basic
# [8/1500] article_id=152466 | prompt_2_evidence_first
# [9/1500] article_id=152466 | prompt_3_conservative
# [10/1500] article_id=29145 | prompt_1_basic
# [11/1500] article_id=29145 | prompt_2_evidence_first
# [12/1500] article_id=29145 | prompt_3_conservative
# [13/1500] article_id=135546 | prompt_1_basic
# [14/1500] article_id=135546 | prompt_2_evidence_first
# [15/1500] article_id=135546 | prompt_3_conservative
# [16/1500] article_id=177111 | prompt_1_basic
# [17/1500] article_id=177111 | prompt_2_evidence_first
# [18/1500] article_id=177111 | prompt_3_conservative
# [19/1500] article_id=152104 | prompt_1_basic
# [20/1500] article_id=152104 | prompt_2_evidence_first
# [21/1500] article_id=152104 | prompt_3_conservative
# [22/1500] article_id=179302 | prompt_1_basic
# [23/1500] article_id=179302 | prompt_2_evidence_first
# [24/1500] article_id=179302 | prompt_3_conservative
# [25/1500] article_id=7617 | prompt_1_basic
# [26/1500] article_id=7617 | prompt_2_evidence_first
# [27/1500] article_id=7617 | prompt_3_conservative
# [28/1500] article_id=103671 | prompt_1_basic
# [29/1500] article_id=103671 | prompt_2_evidence_first
# [30/1500] article_id=103671 | prompt_3_conservative
# [31/1500] article_id=63772 | prompt_1_basic
# [32/1500] article_id=63772 | prompt_2_evidence_first
# [33/1500] article_id=63772 | prompt_3_conservative
# [34/1500] article_id=41810 | prompt_1_basic
# [35/1500] article_id=41810 | prompt_2_evidence_first
# [36/1500] article_id=41810 | prompt_3_conservative
# [37/1500] article_id=178726 | prompt_1_basic
# [38/1500] article_id=178726 | prompt_2_evidence_first
# [39/1500] article_id=178726 | prompt_3_conservative
# [40/1500] article_id=149822 | prompt_1_basic
# [41/1500] article_id=149822 | prompt_2_evidence_first
# [42/1500] article_id=149822 | prompt_3_conservative
# [43/1500] article_id=131661 | prompt_1_basic
# [44/1500] article_id=131661 | prompt_2_evidence_first
# [45/1500] article_id=131661 | prompt_3_conservative
# [46/1500] article_id=138837 | prompt_1_basic
# [47/1500] article_id=138837 | prompt_2_evidence_first
# [48/1500] article_id=138837 | prompt_3_conservative
# [49/1500] article_id=194835 | prompt_1_basic
# [50/1500] article_id=194835 | prompt_2_evidence_first
# [51/1500] article_id=194835 | prompt_3_conservative
# [52/1500] article_id=183671 | prompt_1_basic
# [53/1500] article_id=183671 | prompt_2_evidence_first
# [54/1500] article_id=183671 | prompt_3_conservative
# [55/1500] article_id=24398 | prompt_1_basic
# [56/1500] article_id=24398 | prompt_2_evidence_first
# [57/1500] article_id=24398 | prompt_3_conservative
# [58/1500] article_id=163992 | prompt_1_basic
# [59/1500] article_id=163992 | prompt_2_evidence_first
# [60/1500] article_id=163992 | prompt_3_conservative
# [61/1500] article_id=145274 | prompt_1_basic
# [62/1500] article_id=145274 | prompt_2_evidence_first
# [63/1500] article_id=145274 | prompt_3_conservative
# [64/1500] article_id=146798 | prompt_1_basic
# [65/1500] article_id=146798 | prompt_2_evidence_first
# [66/1500] article_id=146798 | prompt_3_conservative
# [67/1500] article_id=131090 | prompt_1_basic
# [68/1500] article_id=131090 | prompt_2_evidence_first
# [69/1500] article_id=131090 | prompt_3_conservative
# [70/1500] article_id=185437 | prompt_1_basic
# [71/1500] article_id=185437 | prompt_2_evidence_first
# [72/1500] article_id=185437 | prompt_3_conservative
# [73/1500] article_id=43363 | prompt_1_basic
# [74/1500] article_id=43363 | prompt_2_evidence_first
# [75/1500] article_id=43363 | prompt_3_conservative
# [76/1500] article_id=73216 | prompt_1_basic
# [77/1500] article_id=73216 | prompt_2_evidence_first
# [78/1500] article_id=73216 | prompt_3_conservative
# [79/1500] article_id=147316 | prompt_1_basic
# [80/1500] article_id=147316 | prompt_2_evidence_first
# [81/1500] article_id=147316 | prompt_3_conservative
# [82/1500] article_id=127339 | prompt_1_basic
# [83/1500] article_id=127339 | prompt_2_evidence_first
# [84/1500] article_id=127339 | prompt_3_conservative
# [85/1500] article_id=153478 | prompt_1_basic
# [86/1500] article_id=153478 | prompt_2_evidence_first
# [87/1500] article_id=153478 | prompt_3_conservative
# [88/1500] article_id=168931 | prompt_1_basic
# [89/1500] article_id=168931 | prompt_2_evidence_first
# [90/1500] article_id=168931 | prompt_3_conservative
# [91/1500] article_id=168940 | prompt_1_basic
# [92/1500] article_id=168940 | prompt_2_evidence_first
# [93/1500] article_id=168940 | prompt_3_conservative
# [94/1500] article_id=130005 | prompt_1_basic
# [95/1500] article_id=130005 | prompt_2_evidence_first
# [96/1500] article_id=130005 | prompt_3_conservative
# [97/1500] article_id=32859 | prompt_1_basic
# [98/1500] article_id=32859 | prompt_2_evidence_first
# [99/1500] article_id=32859 | prompt_3_conservative
# [100/1500] article_id=232193 | prompt_1_basic
# [101/1500] article_id=232193 | prompt_2_evidence_first
# [102/1500] article_id=232193 | prompt_3_conservative
# [103/1500] article_id=25356 | prompt_1_basic
# [104/1500] article_id=25356 | prompt_2_evidence_first
# [105/1500] article_id=25356 | prompt_3_conservative
# [106/1500] article_id=171352 | prompt_1_basic
# [107/1500] article_id=171352 | prompt_2_evidence_first
# [108/1500] article_id=171352 | prompt_3_conservative
# [109/1500] article_id=158046 | prompt_1_basic
# [110/1500] article_id=158046 | prompt_2_evidence_first
# [111/1500] article_id=158046 | prompt_3_conservative
# [112/1500] article_id=169415 | prompt_1_basic
# [113/1500] article_id=169415 | prompt_2_evidence_first
# [114/1500] article_id=169415 | prompt_3_conservative
# [115/1500] article_id=148342 | prompt_1_basic
# [116/1500] article_id=148342 | prompt_2_evidence_first
# [117/1500] article_id=148342 | prompt_3_conservative
# [118/1500] article_id=58177 | prompt_1_basic
# [119/1500] article_id=58177 | prompt_2_evidence_first
# [120/1500] article_id=58177 | prompt_3_conservative
# [121/1500] article_id=67682 | prompt_1_basic
# [122/1500] article_id=67682 | prompt_2_evidence_first
# [123/1500] article_id=67682 | prompt_3_conservative
# [124/1500] article_id=50340 | prompt_1_basic
# [125/1500] article_id=50340 | prompt_2_evidence_first
# [126/1500] article_id=50340 | prompt_3_conservative
# [127/1500] article_id=195095 | prompt_1_basic
# [128/1500] article_id=195095 | prompt_2_evidence_first
# [129/1500] article_id=195095 | prompt_3_conservative
# [130/1500] article_id=67543 | prompt_1_basic
# [131/1500] article_id=67543 | prompt_2_evidence_first
# [132/1500] article_id=67543 | prompt_3_conservative
# [133/1500] article_id=259079 | prompt_1_basic
# [134/1500] article_id=259079 | prompt_2_evidence_first
# [135/1500] article_id=259079 | prompt_3_conservative
# [136/1500] article_id=180833 | prompt_1_basic
# [137/1500] article_id=180833 | prompt_2_evidence_first
# [138/1500] article_id=180833 | prompt_3_conservative
# [139/1500] article_id=47988 | prompt_1_basic
# [140/1500] article_id=47988 | prompt_2_evidence_first
# [141/1500] article_id=47988 | prompt_3_conservative
# [142/1500] article_id=46039 | prompt_1_basic
# [143/1500] article_id=46039 | prompt_2_evidence_first
# [144/1500] article_id=46039 | prompt_3_conservative
# [145/1500] article_id=164785 | prompt_1_basic
# [146/1500] article_id=164785 | prompt_2_evidence_first
# [147/1500] article_id=164785 | prompt_3_conservative
# [148/1500] article_id=146055 | prompt_1_basic
# [149/1500] article_id=146055 | prompt_2_evidence_first
# [150/1500] article_id=146055 | prompt_3_conservative
# [151/1500] article_id=16803 | prompt_1_basic
# [152/1500] article_id=16803 | prompt_2_evidence_first
# [153/1500] article_id=16803 | prompt_3_conservative
# [154/1500] article_id=128034 | prompt_1_basic
# [155/1500] article_id=128034 | prompt_2_evidence_first
# [156/1500] article_id=128034 | prompt_3_conservative
# [157/1500] article_id=35893 | prompt_1_basic
# [158/1500] article_id=35893 | prompt_2_evidence_first
# [159/1500] article_id=35893 | prompt_3_conservative
# [160/1500] article_id=170248 | prompt_1_basic
# [161/1500] article_id=170248 | prompt_2_evidence_first
# [162/1500] article_id=170248 | prompt_3_conservative
# [163/1500] article_id=160084 | prompt_1_basic
# [164/1500] article_id=160084 | prompt_2_evidence_first
# [165/1500] article_id=160084 | prompt_3_conservative
# [166/1500] article_id=169703 | prompt_1_basic
# [167/1500] article_id=169703 | prompt_2_evidence_first
# [168/1500] article_id=169703 | prompt_3_conservative
# [169/1500] article_id=61979 | prompt_1_basic
# [170/1500] article_id=61979 | prompt_2_evidence_first
# [171/1500] article_id=61979 | prompt_3_conservative
# [172/1500] article_id=133895 | prompt_1_basic
# [173/1500] article_id=133895 | prompt_2_evidence_first
# [174/1500] article_id=133895 | prompt_3_conservative
# [175/1500] article_id=216666 | prompt_1_basic
# [176/1500] article_id=216666 | prompt_2_evidence_first
# [177/1500] article_id=216666 | prompt_3_conservative
# [178/1500] article_id=129218 | prompt_1_basic
# [179/1500] article_id=129218 | prompt_2_evidence_first
# [180/1500] article_id=129218 | prompt_3_conservative
# [181/1500] article_id=37652 | prompt_1_basic
# [182/1500] article_id=37652 | prompt_2_evidence_first
# [183/1500] article_id=37652 | prompt_3_conservative
# [184/1500] article_id=177814 | prompt_1_basic
# [185/1500] article_id=177814 | prompt_2_evidence_first
# [186/1500] article_id=177814 | prompt_3_conservative
# [187/1500] article_id=64869 | prompt_1_basic
# [188/1500] article_id=64869 | prompt_2_evidence_first
# [189/1500] article_id=64869 | prompt_3_conservative
# [190/1500] article_id=68428 | prompt_1_basic
# [191/1500] article_id=68428 | prompt_2_evidence_first
# [192/1500] article_id=68428 | prompt_3_conservative
# [193/1500] article_id=46465 | prompt_1_basic
# [194/1500] article_id=46465 | prompt_2_evidence_first
# [195/1500] article_id=46465 | prompt_3_conservative
# [196/1500] article_id=133238 | prompt_1_basic
# [197/1500] article_id=133238 | prompt_2_evidence_first
# [198/1500] article_id=133238 | prompt_3_conservative
# [199/1500] article_id=64608 | prompt_1_basic
# [200/1500] article_id=64608 | prompt_2_evidence_first
# [201/1500] article_id=64608 | prompt_3_conservative
# [202/1500] article_id=137747 | prompt_1_basic
# [203/1500] article_id=137747 | prompt_2_evidence_first
# [204/1500] article_id=137747 | prompt_3_conservative
# [205/1500] article_id=2880 | prompt_1_basic
# [206/1500] article_id=2880 | prompt_2_evidence_first
# [207/1500] article_id=2880 | prompt_3_conservative
# [208/1500] article_id=21326 | prompt_1_basic
# [209/1500] article_id=21326 | prompt_2_evidence_first
# [210/1500] article_id=21326 | prompt_3_conservative
# [211/1500] article_id=165000 | prompt_1_basic
# [212/1500] article_id=165000 | prompt_2_evidence_first
# [213/1500] article_id=165000 | prompt_3_conservative
# [214/1500] article_id=41887 | prompt_1_basic
# [215/1500] article_id=41887 | prompt_2_evidence_first
# [216/1500] article_id=41887 | prompt_3_conservative
# [217/1500] article_id=3870 | prompt_1_basic
# [218/1500] article_id=3870 | prompt_2_evidence_first
# [219/1500] article_id=3870 | prompt_3_conservative
# [220/1500] article_id=172748 | prompt_1_basic
# [221/1500] article_id=172748 | prompt_2_evidence_first
# [222/1500] article_id=172748 | prompt_3_conservative
# [223/1500] article_id=215513 | prompt_1_basic
# [224/1500] article_id=215513 | prompt_2_evidence_first
# [225/1500] article_id=215513 | prompt_3_conservative
# [226/1500] article_id=180845 | prompt_1_basic
# [227/1500] article_id=180845 | prompt_2_evidence_first
# [228/1500] article_id=180845 | prompt_3_conservative
# [229/1500] article_id=2665 | prompt_1_basic
# [230/1500] article_id=2665 | prompt_2_evidence_first
# [231/1500] article_id=2665 | prompt_3_conservative
# [232/1500] article_id=237728 | prompt_1_basic
# [233/1500] article_id=237728 | prompt_2_evidence_first
# [234/1500] article_id=237728 | prompt_3_conservative
# [235/1500] article_id=152197 | prompt_1_basic
# [236/1500] article_id=152197 | prompt_2_evidence_first
# [237/1500] article_id=152197 | prompt_3_conservative
# [238/1500] article_id=51297 | prompt_1_basic
# [239/1500] article_id=51297 | prompt_2_evidence_first
# [240/1500] article_id=51297 | prompt_3_conservative
# [241/1500] article_id=175691 | prompt_1_basic
# [242/1500] article_id=175691 | prompt_2_evidence_first
# [243/1500] article_id=175691 | prompt_3_conservative
# [244/1500] article_id=33 | prompt_1_basic
# [245/1500] article_id=33 | prompt_2_evidence_first
# [246/1500] article_id=33 | prompt_3_conservative
# [247/1500] article_id=55149 | prompt_1_basic
# [248/1500] article_id=55149 | prompt_2_evidence_first
# [249/1500] article_id=55149 | prompt_3_conservative
# [250/1500] article_id=163378 | prompt_1_basic
# [251/1500] article_id=163378 | prompt_2_evidence_first
# [252/1500] article_id=163378 | prompt_3_conservative
# [253/1500] article_id=208574 | prompt_1_basic
# [254/1500] article_id=208574 | prompt_2_evidence_first
# [255/1500] article_id=208574 | prompt_3_conservative
# [256/1500] article_id=177265 | prompt_1_basic
# [257/1500] article_id=177265 | prompt_2_evidence_first
# [258/1500] article_id=177265 | prompt_3_conservative
# [259/1500] article_id=21802 | prompt_1_basic
# [260/1500] article_id=21802 | prompt_2_evidence_first
# [261/1500] article_id=21802 | prompt_3_conservative
# [262/1500] article_id=14499 | prompt_1_basic
# [263/1500] article_id=14499 | prompt_2_evidence_first
# [264/1500] article_id=14499 | prompt_3_conservative
# [265/1500] article_id=6665 | prompt_1_basic
# [266/1500] article_id=6665 | prompt_2_evidence_first
# [267/1500] article_id=6665 | prompt_3_conservative
# [268/1500] article_id=216203 | prompt_1_basic
# [269/1500] article_id=216203 | prompt_2_evidence_first
# [270/1500] article_id=216203 | prompt_3_conservative
# [271/1500] article_id=128253 | prompt_1_basic
# [272/1500] article_id=128253 | prompt_2_evidence_first
# [273/1500] article_id=128253 | prompt_3_conservative
# [274/1500] article_id=36140 | prompt_1_basic
# [275/1500] article_id=36140 | prompt_2_evidence_first
# [276/1500] article_id=36140 | prompt_3_conservative
# [277/1500] article_id=161090 | prompt_1_basic
# [278/1500] article_id=161090 | prompt_2_evidence_first
# [279/1500] article_id=161090 | prompt_3_conservative
# [280/1500] article_id=41437 | prompt_1_basic
# [281/1500] article_id=41437 | prompt_2_evidence_first
# [282/1500] article_id=41437 | prompt_3_conservative
# [283/1500] article_id=197183 | prompt_1_basic
# [284/1500] article_id=197183 | prompt_2_evidence_first
# [285/1500] article_id=197183 | prompt_3_conservative
# [286/1500] article_id=160586 | prompt_1_basic
# [287/1500] article_id=160586 | prompt_2_evidence_first
# [288/1500] article_id=160586 | prompt_3_conservative
# [289/1500] article_id=206621 | prompt_1_basic
# [290/1500] article_id=206621 | prompt_2_evidence_first
# [291/1500] article_id=206621 | prompt_3_conservative
# [292/1500] article_id=178213 | prompt_1_basic
# [293/1500] article_id=178213 | prompt_2_evidence_first
# [294/1500] article_id=178213 | prompt_3_conservative
# [295/1500] article_id=61889 | prompt_1_basic
# [296/1500] article_id=61889 | prompt_2_evidence_first
# [297/1500] article_id=61889 | prompt_3_conservative
# [298/1500] article_id=161065 | prompt_1_basic
# [299/1500] article_id=161065 | prompt_2_evidence_first
# [300/1500] article_id=161065 | prompt_3_conservative
# [301/1500] article_id=39612 | prompt_1_basic
# [302/1500] article_id=39612 | prompt_2_evidence_first
# [303/1500] article_id=39612 | prompt_3_conservative
# [304/1500] article_id=168597 | prompt_1_basic
# [305/1500] article_id=168597 | prompt_2_evidence_first
# [306/1500] article_id=168597 | prompt_3_conservative
# [307/1500] article_id=45900 | prompt_1_basic
# [308/1500] article_id=45900 | prompt_2_evidence_first
# [309/1500] article_id=45900 | prompt_3_conservative
# [310/1500] article_id=219460 | prompt_1_basic
# [311/1500] article_id=219460 | prompt_2_evidence_first
# [312/1500] article_id=219460 | prompt_3_conservative
# [313/1500] article_id=40397 | prompt_1_basic
# [314/1500] article_id=40397 | prompt_2_evidence_first
# [315/1500] article_id=40397 | prompt_3_conservative
# [316/1500] article_id=156284 | prompt_1_basic
# [317/1500] article_id=156284 | prompt_2_evidence_first
# [318/1500] article_id=156284 | prompt_3_conservative
# [319/1500] article_id=3322 | prompt_1_basic
# [320/1500] article_id=3322 | prompt_2_evidence_first
# [321/1500] article_id=3322 | prompt_3_conservative
# [322/1500] article_id=234851 | prompt_1_basic
# [323/1500] article_id=234851 | prompt_2_evidence_first
# [324/1500] article_id=234851 | prompt_3_conservative
# [325/1500] article_id=20250 | prompt_1_basic
# [326/1500] article_id=20250 | prompt_2_evidence_first
# [327/1500] article_id=20250 | prompt_3_conservative
# [328/1500] article_id=17332 | prompt_1_basic
# [329/1500] article_id=17332 | prompt_2_evidence_first
# [330/1500] article_id=17332 | prompt_3_conservative
# [331/1500] article_id=251429 | prompt_1_basic
# [332/1500] article_id=251429 | prompt_2_evidence_first
# [333/1500] article_id=251429 | prompt_3_conservative
# [334/1500] article_id=149016 | prompt_1_basic
# [335/1500] article_id=149016 | prompt_2_evidence_first
# [336/1500] article_id=149016 | prompt_3_conservative
# [337/1500] article_id=68652 | prompt_1_basic
# [338/1500] article_id=68652 | prompt_2_evidence_first
# [339/1500] article_id=68652 | prompt_3_conservative
# [340/1500] article_id=136786 | prompt_1_basic
# [341/1500] article_id=136786 | prompt_2_evidence_first
# [342/1500] article_id=136786 | prompt_3_conservative
# [343/1500] article_id=232338 | prompt_1_basic
# [344/1500] article_id=232338 | prompt_2_evidence_first
# [345/1500] article_id=232338 | prompt_3_conservative
# [346/1500] article_id=154110 | prompt_1_basic
# [347/1500] article_id=154110 | prompt_2_evidence_first
# [348/1500] article_id=154110 | prompt_3_conservative
# [349/1500] article_id=43862 | prompt_1_basic
# [350/1500] article_id=43862 | prompt_2_evidence_first
# [351/1500] article_id=43862 | prompt_3_conservative
# [352/1500] article_id=213602 | prompt_1_basic
# [353/1500] article_id=213602 | prompt_2_evidence_first
# [354/1500] article_id=213602 | prompt_3_conservative
# [355/1500] article_id=36977 | prompt_1_basic
# [356/1500] article_id=36977 | prompt_2_evidence_first
# [357/1500] article_id=36977 | prompt_3_conservative
# [358/1500] article_id=201947 | prompt_1_basic
# [359/1500] article_id=201947 | prompt_2_evidence_first
# [360/1500] article_id=201947 | prompt_3_conservative
# [361/1500] article_id=16588 | prompt_1_basic
# [362/1500] article_id=16588 | prompt_2_evidence_first
# [363/1500] article_id=16588 | prompt_3_conservative
# [364/1500] article_id=49504 | prompt_1_basic
# [365/1500] article_id=49504 | prompt_2_evidence_first
# [366/1500] article_id=49504 | prompt_3_conservative
# [367/1500] article_id=146287 | prompt_1_basic
# [368/1500] article_id=146287 | prompt_2_evidence_first
# [369/1500] article_id=146287 | prompt_3_conservative
# [370/1500] article_id=218210 | prompt_1_basic
# [371/1500] article_id=218210 | prompt_2_evidence_first
# [372/1500] article_id=218210 | prompt_3_conservative
# [373/1500] article_id=14914 | prompt_1_basic
# [374/1500] article_id=14914 | prompt_2_evidence_first
# [375/1500] article_id=14914 | prompt_3_conservative
# [376/1500] article_id=126353 | prompt_1_basic
# [377/1500] article_id=126353 | prompt_2_evidence_first
# [378/1500] article_id=126353 | prompt_3_conservative
# [379/1500] article_id=157455 | prompt_1_basic
# [380/1500] article_id=157455 | prompt_2_evidence_first
# [381/1500] article_id=157455 | prompt_3_conservative
# [382/1500] article_id=35109 | prompt_1_basic
# [383/1500] article_id=35109 | prompt_2_evidence_first
# [384/1500] article_id=35109 | prompt_3_conservative
# [385/1500] article_id=205367 | prompt_1_basic
# [386/1500] article_id=205367 | prompt_2_evidence_first
# [387/1500] article_id=205367 | prompt_3_conservative
# [388/1500] article_id=131376 | prompt_1_basic
# [389/1500] article_id=131376 | prompt_2_evidence_first
# [390/1500] article_id=131376 | prompt_3_conservative
# [391/1500] article_id=131578 | prompt_1_basic
# [392/1500] article_id=131578 | prompt_2_evidence_first
# [393/1500] article_id=131578 | prompt_3_conservative
# [394/1500] article_id=76514 | prompt_1_basic
# [395/1500] article_id=76514 | prompt_2_evidence_first
# [396/1500] article_id=76514 | prompt_3_conservative
# [397/1500] article_id=66185 | prompt_1_basic
# [398/1500] article_id=66185 | prompt_2_evidence_first
# [399/1500] article_id=66185 | prompt_3_conservative
# [400/1500] article_id=214946 | prompt_1_basic
# [401/1500] article_id=214946 | prompt_2_evidence_first
# [402/1500] article_id=214946 | prompt_3_conservative
# [403/1500] article_id=128070 | prompt_1_basic
# [404/1500] article_id=128070 | prompt_2_evidence_first
# [405/1500] article_id=128070 | prompt_3_conservative
# [406/1500] article_id=31269 | prompt_1_basic
# [407/1500] article_id=31269 | prompt_2_evidence_first
# [408/1500] article_id=31269 | prompt_3_conservative
# [409/1500] article_id=54021 | prompt_1_basic
# [410/1500] article_id=54021 | prompt_2_evidence_first
# [411/1500] article_id=54021 | prompt_3_conservative
# [412/1500] article_id=231986 | prompt_1_basic
# [413/1500] article_id=231986 | prompt_2_evidence_first
# [414/1500] article_id=231986 | prompt_3_conservative
# [415/1500] article_id=165645 | prompt_1_basic
# [416/1500] article_id=165645 | prompt_2_evidence_first
# [417/1500] article_id=165645 | prompt_3_conservative
# [418/1500] article_id=195745 | prompt_1_basic
# [419/1500] article_id=195745 | prompt_2_evidence_first
# [420/1500] article_id=195745 | prompt_3_conservative
# [421/1500] article_id=216812 | prompt_1_basic
# [422/1500] article_id=216812 | prompt_2_evidence_first
# [423/1500] article_id=216812 | prompt_3_conservative
# [424/1500] article_id=125084 | prompt_1_basic
# [425/1500] article_id=125084 | prompt_2_evidence_first
# [426/1500] article_id=125084 | prompt_3_conservative
# [427/1500] article_id=242525 | prompt_1_basic
# [428/1500] article_id=242525 | prompt_2_evidence_first
# [429/1500] article_id=242525 | prompt_3_conservative
# [430/1500] article_id=67765 | prompt_1_basic
# [431/1500] article_id=67765 | prompt_2_evidence_first
# [432/1500] article_id=67765 | prompt_3_conservative
# [433/1500] article_id=189142 | prompt_1_basic
# [434/1500] article_id=189142 | prompt_2_evidence_first
# [435/1500] article_id=189142 | prompt_3_conservative
# [436/1500] article_id=68456 | prompt_1_basic
# [437/1500] article_id=68456 | prompt_2_evidence_first
# [438/1500] article_id=68456 | prompt_3_conservative
# [439/1500] article_id=248023 | prompt_1_basic
# [440/1500] article_id=248023 | prompt_2_evidence_first
# [441/1500] article_id=248023 | prompt_3_conservative
# [442/1500] article_id=141082 | prompt_1_basic
# [443/1500] article_id=141082 | prompt_2_evidence_first
# [444/1500] article_id=141082 | prompt_3_conservative
# [445/1500] article_id=49823 | prompt_1_basic
# [446/1500] article_id=49823 | prompt_2_evidence_first
# [447/1500] article_id=49823 | prompt_3_conservative
# [448/1500] article_id=61191 | prompt_1_basic
# [449/1500] article_id=61191 | prompt_2_evidence_first
# [450/1500] article_id=61191 | prompt_3_conservative
# [451/1500] article_id=69532 | prompt_1_basic
# [452/1500] article_id=69532 | prompt_2_evidence_first
# [453/1500] article_id=69532 | prompt_3_conservative
# [454/1500] article_id=196181 | prompt_1_basic
# [455/1500] article_id=196181 | prompt_2_evidence_first
# [456/1500] article_id=196181 | prompt_3_conservative
# [457/1500] article_id=197312 | prompt_1_basic
# [458/1500] article_id=197312 | prompt_2_evidence_first
# [459/1500] article_id=197312 | prompt_3_conservative
# [460/1500] article_id=54012 | prompt_1_basic
# [461/1500] article_id=54012 | prompt_2_evidence_first
# [462/1500] article_id=54012 | prompt_3_conservative
# [463/1500] article_id=57543 | prompt_1_basic
# [464/1500] article_id=57543 | prompt_2_evidence_first
# [465/1500] article_id=57543 | prompt_3_conservative
# [466/1500] article_id=10130 | prompt_1_basic
# [467/1500] article_id=10130 | prompt_2_evidence_first
# [468/1500] article_id=10130 | prompt_3_conservative
# [469/1500] article_id=141017 | prompt_1_basic
# [470/1500] article_id=141017 | prompt_2_evidence_first
# [471/1500] article_id=141017 | prompt_3_conservative
# [472/1500] article_id=200166 | prompt_1_basic
# [473/1500] article_id=200166 | prompt_2_evidence_first
# [474/1500] article_id=200166 | prompt_3_conservative
# [475/1500] article_id=152721 | prompt_1_basic
# [476/1500] article_id=152721 | prompt_2_evidence_first
# [477/1500] article_id=152721 | prompt_3_conservative
# [478/1500] article_id=134245 | prompt_1_basic
# [479/1500] article_id=134245 | prompt_2_evidence_first
# [480/1500] article_id=134245 | prompt_3_conservative
# [481/1500] article_id=199950 | prompt_1_basic
# [482/1500] article_id=199950 | prompt_2_evidence_first
# [483/1500] article_id=199950 | prompt_3_conservative
# [484/1500] article_id=200250 | prompt_1_basic
# [485/1500] article_id=200250 | prompt_2_evidence_first
# [486/1500] article_id=200250 | prompt_3_conservative
# [487/1500] article_id=21136 | prompt_1_basic
# [488/1500] article_id=21136 | prompt_2_evidence_first
# [489/1500] article_id=21136 | prompt_3_conservative
# [490/1500] article_id=65243 | prompt_1_basic
# [491/1500] article_id=65243 | prompt_2_evidence_first
# [492/1500] article_id=65243 | prompt_3_conservative
# [493/1500] article_id=232875 | prompt_1_basic
# [494/1500] article_id=232875 | prompt_2_evidence_first
# [495/1500] article_id=232875 | prompt_3_conservative
# [496/1500] article_id=216947 | prompt_1_basic
# [497/1500] article_id=216947 | prompt_2_evidence_first
# [498/1500] article_id=216947 | prompt_3_conservative
# [499/1500] article_id=177055 | prompt_1_basic
# [500/1500] article_id=177055 | prompt_2_evidence_first
# [501/1500] article_id=177055 | prompt_3_conservative
# [502/1500] article_id=30510 | prompt_1_basic
# [503/1500] article_id=30510 | prompt_2_evidence_first
# [504/1500] article_id=30510 | prompt_3_conservative
# [505/1500] article_id=12299 | prompt_1_basic
# [506/1500] article_id=12299 | prompt_2_evidence_first
# [507/1500] article_id=12299 | prompt_3_conservative
# [508/1500] article_id=145258 | prompt_1_basic
# [509/1500] article_id=145258 | prompt_2_evidence_first
# [510/1500] article_id=145258 | prompt_3_conservative
# [511/1500] article_id=55067 | prompt_1_basic
# [512/1500] article_id=55067 | prompt_2_evidence_first
# [513/1500] article_id=55067 | prompt_3_conservative
# [514/1500] article_id=170558 | prompt_1_basic
# [515/1500] article_id=170558 | prompt_2_evidence_first
# [516/1500] article_id=170558 | prompt_3_conservative
# [517/1500] article_id=172689 | prompt_1_basic
# [518/1500] article_id=172689 | prompt_2_evidence_first
# [519/1500] article_id=172689 | prompt_3_conservative
# [520/1500] article_id=45695 | prompt_1_basic
# [521/1500] article_id=45695 | prompt_2_evidence_first
# [522/1500] article_id=45695 | prompt_3_conservative
# [523/1500] article_id=207871 | prompt_1_basic
# [524/1500] article_id=207871 | prompt_2_evidence_first
# [525/1500] article_id=207871 | prompt_3_conservative
# [526/1500] article_id=32128 | prompt_1_basic
# [527/1500] article_id=32128 | prompt_2_evidence_first
# [528/1500] article_id=32128 | prompt_3_conservative
# [529/1500] article_id=68600 | prompt_1_basic
# [530/1500] article_id=68600 | prompt_2_evidence_first
# [531/1500] article_id=68600 | prompt_3_conservative
# [532/1500] article_id=127587 | prompt_1_basic
# [533/1500] article_id=127587 | prompt_2_evidence_first
# [534/1500] article_id=127587 | prompt_3_conservative
# [535/1500] article_id=206509 | prompt_1_basic
# [536/1500] article_id=206509 | prompt_2_evidence_first
# [537/1500] article_id=206509 | prompt_3_conservative
# [538/1500] article_id=46060 | prompt_1_basic
# [539/1500] article_id=46060 | prompt_2_evidence_first
# [540/1500] article_id=46060 | prompt_3_conservative
# [541/1500] article_id=154161 | prompt_1_basic
# [542/1500] article_id=154161 | prompt_2_evidence_first
# [543/1500] article_id=154161 | prompt_3_conservative
# [544/1500] article_id=65704 | prompt_1_basic
# [545/1500] article_id=65704 | prompt_2_evidence_first
# [546/1500] article_id=65704 | prompt_3_conservative
# [547/1500] article_id=172890 | prompt_1_basic
# [548/1500] article_id=172890 | prompt_2_evidence_first
# [549/1500] article_id=172890 | prompt_3_conservative
# [550/1500] article_id=73524 | prompt_1_basic
# [551/1500] article_id=73524 | prompt_2_evidence_first
# [552/1500] article_id=73524 | prompt_3_conservative
# [553/1500] article_id=154503 | prompt_1_basic
# [554/1500] article_id=154503 | prompt_2_evidence_first
# [555/1500] article_id=154503 | prompt_3_conservative
# [556/1500] article_id=182420 | prompt_1_basic
# [557/1500] article_id=182420 | prompt_2_evidence_first
# [558/1500] article_id=182420 | prompt_3_conservative
# [559/1500] article_id=131411 | prompt_1_basic
# [560/1500] article_id=131411 | prompt_2_evidence_first
# [561/1500] article_id=131411 | prompt_3_conservative
# [562/1500] article_id=246927 | prompt_1_basic
# [563/1500] article_id=246927 | prompt_2_evidence_first
# [564/1500] article_id=246927 | prompt_3_conservative
# [565/1500] article_id=62377 | prompt_1_basic
# [566/1500] article_id=62377 | prompt_2_evidence_first
# [567/1500] article_id=62377 | prompt_3_conservative
# [568/1500] article_id=159470 | prompt_1_basic
# [569/1500] article_id=159470 | prompt_2_evidence_first
# [570/1500] article_id=159470 | prompt_3_conservative
# [571/1500] article_id=216706 | prompt_1_basic
# [572/1500] article_id=216706 | prompt_2_evidence_first
# [573/1500] article_id=216706 | prompt_3_conservative
# [574/1500] article_id=176877 | prompt_1_basic
# [575/1500] article_id=176877 | prompt_2_evidence_first
# [576/1500] article_id=176877 | prompt_3_conservative
# [577/1500] article_id=5021 | prompt_1_basic
# [578/1500] article_id=5021 | prompt_2_evidence_first
# [579/1500] article_id=5021 | prompt_3_conservative
# [580/1500] article_id=151533 | prompt_1_basic
# [581/1500] article_id=151533 | prompt_2_evidence_first
# [582/1500] article_id=151533 | prompt_3_conservative
# [583/1500] article_id=136689 | prompt_1_basic
# [584/1500] article_id=136689 | prompt_2_evidence_first
# [585/1500] article_id=136689 | prompt_3_conservative
# [586/1500] article_id=181194 | prompt_1_basic
# [587/1500] article_id=181194 | prompt_2_evidence_first
# [588/1500] article_id=181194 | prompt_3_conservative
# [589/1500] article_id=142870 | prompt_1_basic
# [590/1500] article_id=142870 | prompt_2_evidence_first
# [591/1500] article_id=142870 | prompt_3_conservative
# [592/1500] article_id=155557 | prompt_1_basic
# [593/1500] article_id=155557 | prompt_2_evidence_first
# [594/1500] article_id=155557 | prompt_3_conservative
# [595/1500] article_id=19274 | prompt_1_basic
# [596/1500] article_id=19274 | prompt_2_evidence_first
# [597/1500] article_id=19274 | prompt_3_conservative
# [598/1500] article_id=230402 | prompt_1_basic
# [599/1500] article_id=230402 | prompt_2_evidence_first
# [600/1500] article_id=230402 | prompt_3_conservative
# [601/1500] article_id=164271 | prompt_1_basic
# [602/1500] article_id=164271 | prompt_2_evidence_first
# [603/1500] article_id=164271 | prompt_3_conservative
# [604/1500] article_id=149457 | prompt_1_basic
# [605/1500] article_id=149457 | prompt_2_evidence_first
# [606/1500] article_id=149457 | prompt_3_conservative
# [607/1500] article_id=207938 | prompt_1_basic
# [608/1500] article_id=207938 | prompt_2_evidence_first
# [609/1500] article_id=207938 | prompt_3_conservative
# [610/1500] article_id=144195 | prompt_1_basic
# [611/1500] article_id=144195 | prompt_2_evidence_first
# [612/1500] article_id=144195 | prompt_3_conservative
# [613/1500] article_id=32270 | prompt_1_basic
# [614/1500] article_id=32270 | prompt_2_evidence_first
# [615/1500] article_id=32270 | prompt_3_conservative
# [616/1500] article_id=248467 | prompt_1_basic
# [617/1500] article_id=248467 | prompt_2_evidence_first
# [618/1500] article_id=248467 | prompt_3_conservative
# [619/1500] article_id=147894 | prompt_1_basic
# [620/1500] article_id=147894 | prompt_2_evidence_first
# [621/1500] article_id=147894 | prompt_3_conservative
# [622/1500] article_id=41779 | prompt_1_basic
# [623/1500] article_id=41779 | prompt_2_evidence_first
# [624/1500] article_id=41779 | prompt_3_conservative
# [625/1500] article_id=167786 | prompt_1_basic
# [626/1500] article_id=167786 | prompt_2_evidence_first
# [627/1500] article_id=167786 | prompt_3_conservative
# [628/1500] article_id=138105 | prompt_1_basic
# [629/1500] article_id=138105 | prompt_2_evidence_first
# [630/1500] article_id=138105 | prompt_3_conservative
# [631/1500] article_id=25549 | prompt_1_basic
# [632/1500] article_id=25549 | prompt_2_evidence_first
# [633/1500] article_id=25549 | prompt_3_conservative
# [634/1500] article_id=142731 | prompt_1_basic
# [635/1500] article_id=142731 | prompt_2_evidence_first
# [636/1500] article_id=142731 | prompt_3_conservative
# [637/1500] article_id=154307 | prompt_1_basic
# [638/1500] article_id=154307 | prompt_2_evidence_first
# [639/1500] article_id=154307 | prompt_3_conservative
# [640/1500] article_id=164530 | prompt_1_basic
# [641/1500] article_id=164530 | prompt_2_evidence_first
# [642/1500] article_id=164530 | prompt_3_conservative
# [643/1500] article_id=130526 | prompt_1_basic
# [644/1500] article_id=130526 | prompt_2_evidence_first
# [645/1500] article_id=130526 | prompt_3_conservative
# [646/1500] article_id=62297 | prompt_1_basic
# [647/1500] article_id=62297 | prompt_2_evidence_first
# [648/1500] article_id=62297 | prompt_3_conservative
# [649/1500] article_id=171335 | prompt_1_basic
# [650/1500] article_id=171335 | prompt_2_evidence_first
# [651/1500] article_id=171335 | prompt_3_conservative
# [652/1500] article_id=130837 | prompt_1_basic
# [653/1500] article_id=130837 | prompt_2_evidence_first
# [654/1500] article_id=130837 | prompt_3_conservative
# [655/1500] article_id=167233 | prompt_1_basic
# [656/1500] article_id=167233 | prompt_2_evidence_first
# [657/1500] article_id=167233 | prompt_3_conservative
# [658/1500] article_id=68362 | prompt_1_basic
# [659/1500] article_id=68362 | prompt_2_evidence_first
# [660/1500] article_id=68362 | prompt_3_conservative
# [661/1500] article_id=163835 | prompt_1_basic
# [662/1500] article_id=163835 | prompt_2_evidence_first
# [663/1500] article_id=163835 | prompt_3_conservative
# [664/1500] article_id=213084 | prompt_1_basic
# [665/1500] article_id=213084 | prompt_2_evidence_first
# [666/1500] article_id=213084 | prompt_3_conservative
# [667/1500] article_id=191318 | prompt_1_basic
# [668/1500] article_id=191318 | prompt_2_evidence_first
# [669/1500] article_id=191318 | prompt_3_conservative
# [670/1500] article_id=69061 | prompt_1_basic
# [671/1500] article_id=69061 | prompt_2_evidence_first
# [672/1500] article_id=69061 | prompt_3_conservative
# [673/1500] article_id=155846 | prompt_1_basic
# [674/1500] article_id=155846 | prompt_2_evidence_first
# [675/1500] article_id=155846 | prompt_3_conservative
# [676/1500] article_id=46717 | prompt_1_basic
# [677/1500] article_id=46717 | prompt_2_evidence_first
# [678/1500] article_id=46717 | prompt_3_conservative
# [679/1500] article_id=74849 | prompt_1_basic
# [680/1500] article_id=74849 | prompt_2_evidence_first
# [681/1500] article_id=74849 | prompt_3_conservative
# [682/1500] article_id=166508 | prompt_1_basic
# [683/1500] article_id=166508 | prompt_2_evidence_first
# [684/1500] article_id=166508 | prompt_3_conservative
# [685/1500] article_id=201928 | prompt_1_basic
# [686/1500] article_id=201928 | prompt_2_evidence_first
# [687/1500] article_id=201928 | prompt_3_conservative
# [688/1500] article_id=30917 | prompt_1_basic
# [689/1500] article_id=30917 | prompt_2_evidence_first
# [690/1500] article_id=30917 | prompt_3_conservative
# [691/1500] article_id=216967 | prompt_1_basic
# [692/1500] article_id=216967 | prompt_2_evidence_first
# [693/1500] article_id=216967 | prompt_3_conservative
# [694/1500] article_id=145168 | prompt_1_basic
# [695/1500] article_id=145168 | prompt_2_evidence_first
# [696/1500] article_id=145168 | prompt_3_conservative
# [697/1500] article_id=24771 | prompt_1_basic
# [698/1500] article_id=24771 | prompt_2_evidence_first
# [699/1500] article_id=24771 | prompt_3_conservative
# [700/1500] article_id=42824 | prompt_1_basic
# [701/1500] article_id=42824 | prompt_2_evidence_first
# [702/1500] article_id=42824 | prompt_3_conservative
# [703/1500] article_id=47866 | prompt_1_basic
# [704/1500] article_id=47866 | prompt_2_evidence_first
# [705/1500] article_id=47866 | prompt_3_conservative
# [706/1500] article_id=165142 | prompt_1_basic
# [707/1500] article_id=165142 | prompt_2_evidence_first
# [708/1500] article_id=165142 | prompt_3_conservative
# [709/1500] article_id=164634 | prompt_1_basic
# [710/1500] article_id=164634 | prompt_2_evidence_first
# [711/1500] article_id=164634 | prompt_3_conservative
# [712/1500] article_id=156730 | prompt_1_basic
# [713/1500] article_id=156730 | prompt_2_evidence_first
# [714/1500] article_id=156730 | prompt_3_conservative
# [715/1500] article_id=151881 | prompt_1_basic
# [716/1500] article_id=151881 | prompt_2_evidence_first
# [717/1500] article_id=151881 | prompt_3_conservative
# [718/1500] article_id=167093 | prompt_1_basic
# [719/1500] article_id=167093 | prompt_2_evidence_first
# [720/1500] article_id=167093 | prompt_3_conservative
# [721/1500] article_id=34510 | prompt_1_basic
# [722/1500] article_id=34510 | prompt_2_evidence_first
# [723/1500] article_id=34510 | prompt_3_conservative
# [724/1500] article_id=1877 | prompt_1_basic
# [725/1500] article_id=1877 | prompt_2_evidence_first
# [726/1500] article_id=1877 | prompt_3_conservative
# [727/1500] article_id=195365 | prompt_1_basic
# [728/1500] article_id=195365 | prompt_2_evidence_first
# [729/1500] article_id=195365 | prompt_3_conservative
# [730/1500] article_id=176555 | prompt_1_basic
# [731/1500] article_id=176555 | prompt_2_evidence_first
# [732/1500] article_id=176555 | prompt_3_conservative
# [733/1500] article_id=15854 | prompt_1_basic
# [734/1500] article_id=15854 | prompt_2_evidence_first
# [735/1500] article_id=15854 | prompt_3_conservative
# [736/1500] article_id=128598 | prompt_1_basic
# [737/1500] article_id=128598 | prompt_2_evidence_first
# [738/1500] article_id=128598 | prompt_3_conservative
# [739/1500] article_id=71391 | prompt_1_basic
# [740/1500] article_id=71391 | prompt_2_evidence_first
# [741/1500] article_id=71391 | prompt_3_conservative
# [742/1500] article_id=142290 | prompt_1_basic
# [743/1500] article_id=142290 | prompt_2_evidence_first
# [744/1500] article_id=142290 | prompt_3_conservative
# [745/1500] article_id=109692 | prompt_1_basic
# [746/1500] article_id=109692 | prompt_2_evidence_first
# [747/1500] article_id=109692 | prompt_3_conservative
# [748/1500] article_id=198565 | prompt_1_basic
# [749/1500] article_id=198565 | prompt_2_evidence_first
# [750/1500] article_id=198565 | prompt_3_conservative
# [751/1500] article_id=157891 | prompt_1_basic
# [752/1500] article_id=157891 | prompt_2_evidence_first
# [753/1500] article_id=157891 | prompt_3_conservative
# [754/1500] article_id=143039 | prompt_1_basic
# [755/1500] article_id=143039 | prompt_2_evidence_first
# [756/1500] article_id=143039 | prompt_3_conservative
# [757/1500] article_id=5449 | prompt_1_basic
# [758/1500] article_id=5449 | prompt_2_evidence_first
# [759/1500] article_id=5449 | prompt_3_conservative
# [760/1500] article_id=150457 | prompt_1_basic
# [761/1500] article_id=150457 | prompt_2_evidence_first
# [762/1500] article_id=150457 | prompt_3_conservative
# [763/1500] article_id=172405 | prompt_1_basic
# [764/1500] article_id=172405 | prompt_2_evidence_first
# [765/1500] article_id=172405 | prompt_3_conservative
# [766/1500] article_id=151256 | prompt_1_basic
# [767/1500] article_id=151256 | prompt_2_evidence_first
# [768/1500] article_id=151256 | prompt_3_conservative
# [769/1500] article_id=177485 | prompt_1_basic
# [770/1500] article_id=177485 | prompt_2_evidence_first
# [771/1500] article_id=177485 | prompt_3_conservative
# [772/1500] article_id=23252 | prompt_1_basic
# [773/1500] article_id=23252 | prompt_2_evidence_first
# [774/1500] article_id=23252 | prompt_3_conservative
# [775/1500] article_id=130994 | prompt_1_basic
# [776/1500] article_id=130994 | prompt_2_evidence_first
# [777/1500] article_id=130994 | prompt_3_conservative
# [778/1500] article_id=179198 | prompt_1_basic
# [779/1500] article_id=179198 | prompt_2_evidence_first
# [780/1500] article_id=179198 | prompt_3_conservative
# [781/1500] article_id=204356 | prompt_1_basic
# [782/1500] article_id=204356 | prompt_2_evidence_first
# [783/1500] article_id=204356 | prompt_3_conservative
# [784/1500] article_id=28276 | prompt_1_basic
# [785/1500] article_id=28276 | prompt_2_evidence_first
# [786/1500] article_id=28276 | prompt_3_conservative
# [787/1500] article_id=191280 | prompt_1_basic
# [788/1500] article_id=191280 | prompt_2_evidence_first
# [789/1500] article_id=191280 | prompt_3_conservative
# [790/1500] article_id=19730 | prompt_1_basic
# [791/1500] article_id=19730 | prompt_2_evidence_first
# [792/1500] article_id=19730 | prompt_3_conservative
# [793/1500] article_id=171702 | prompt_1_basic
# [794/1500] article_id=171702 | prompt_2_evidence_first
# [795/1500] article_id=171702 | prompt_3_conservative
# [796/1500] article_id=169085 | prompt_1_basic
# [797/1500] article_id=169085 | prompt_2_evidence_first
# [798/1500] article_id=169085 | prompt_3_conservative
# [799/1500] article_id=49572 | prompt_1_basic
# [800/1500] article_id=49572 | prompt_2_evidence_first
# [801/1500] article_id=49572 | prompt_3_conservative
# [802/1500] article_id=133745 | prompt_1_basic
# [803/1500] article_id=133745 | prompt_2_evidence_first
# [804/1500] article_id=133745 | prompt_3_conservative
# [805/1500] article_id=155205 | prompt_1_basic
# [806/1500] article_id=155205 | prompt_2_evidence_first
# [807/1500] article_id=155205 | prompt_3_conservative
# [808/1500] article_id=33595 | prompt_1_basic
# [809/1500] article_id=33595 | prompt_2_evidence_first
# [810/1500] article_id=33595 | prompt_3_conservative
# [811/1500] article_id=145365 | prompt_1_basic
# [812/1500] article_id=145365 | prompt_2_evidence_first
# [813/1500] article_id=145365 | prompt_3_conservative
# [814/1500] article_id=178235 | prompt_1_basic
# [815/1500] article_id=178235 | prompt_2_evidence_first
# [816/1500] article_id=178235 | prompt_3_conservative
# [817/1500] article_id=164583 | prompt_1_basic
# [818/1500] article_id=164583 | prompt_2_evidence_first
# [819/1500] article_id=164583 | prompt_3_conservative
# [820/1500] article_id=155391 | prompt_1_basic
# [821/1500] article_id=155391 | prompt_2_evidence_first
# [822/1500] article_id=155391 | prompt_3_conservative
# [823/1500] article_id=42169 | prompt_1_basic
# [824/1500] article_id=42169 | prompt_2_evidence_first
# [825/1500] article_id=42169 | prompt_3_conservative
# [826/1500] article_id=237390 | prompt_1_basic
# [827/1500] article_id=237390 | prompt_2_evidence_first
# [828/1500] article_id=237390 | prompt_3_conservative
# [829/1500] article_id=159039 | prompt_1_basic
# [830/1500] article_id=159039 | prompt_2_evidence_first
# [831/1500] article_id=159039 | prompt_3_conservative
# [832/1500] article_id=132822 | prompt_1_basic
# [833/1500] article_id=132822 | prompt_2_evidence_first
# [834/1500] article_id=132822 | prompt_3_conservative
# [835/1500] article_id=255820 | prompt_1_basic
# [836/1500] article_id=255820 | prompt_2_evidence_first
# [837/1500] article_id=255820 | prompt_3_conservative
# [838/1500] article_id=231350 | prompt_1_basic
# [839/1500] article_id=231350 | prompt_2_evidence_first
# [840/1500] article_id=231350 | prompt_3_conservative
# [841/1500] article_id=186787 | prompt_1_basic
# [842/1500] article_id=186787 | prompt_2_evidence_first
# [843/1500] article_id=186787 | prompt_3_conservative
# [844/1500] article_id=130864 | prompt_1_basic
# [845/1500] article_id=130864 | prompt_2_evidence_first
# [846/1500] article_id=130864 | prompt_3_conservative
# [847/1500] article_id=201913 | prompt_1_basic
# [848/1500] article_id=201913 | prompt_2_evidence_first
# [849/1500] article_id=201913 | prompt_3_conservative
# [850/1500] article_id=166454 | prompt_1_basic
# [851/1500] article_id=166454 | prompt_2_evidence_first
# [852/1500] article_id=166454 | prompt_3_conservative
# [853/1500] article_id=127472 | prompt_1_basic
# [854/1500] article_id=127472 | prompt_2_evidence_first
# [855/1500] article_id=127472 | prompt_3_conservative
# [856/1500] article_id=214579 | prompt_1_basic
# [857/1500] article_id=214579 | prompt_2_evidence_first
# [858/1500] article_id=214579 | prompt_3_conservative
# [859/1500] article_id=181336 | prompt_1_basic
# [860/1500] article_id=181336 | prompt_2_evidence_first
# [861/1500] article_id=181336 | prompt_3_conservative
# [862/1500] article_id=50654 | prompt_1_basic
# [863/1500] article_id=50654 | prompt_2_evidence_first
# [864/1500] article_id=50654 | prompt_3_conservative
# [865/1500] article_id=134434 | prompt_1_basic
# [866/1500] article_id=134434 | prompt_2_evidence_first
# [867/1500] article_id=134434 | prompt_3_conservative
# [868/1500] article_id=43557 | prompt_1_basic
# [869/1500] article_id=43557 | prompt_2_evidence_first
# [870/1500] article_id=43557 | prompt_3_conservative
# [871/1500] article_id=177534 | prompt_1_basic
# [872/1500] article_id=177534 | prompt_2_evidence_first
# [873/1500] article_id=177534 | prompt_3_conservative
# [874/1500] article_id=69828 | prompt_1_basic
# [875/1500] article_id=69828 | prompt_2_evidence_first
# [876/1500] article_id=69828 | prompt_3_conservative
# [877/1500] article_id=150864 | prompt_1_basic
# [878/1500] article_id=150864 | prompt_2_evidence_first
# [879/1500] article_id=150864 | prompt_3_conservative
# [880/1500] article_id=171184 | prompt_1_basic
# [881/1500] article_id=171184 | prompt_2_evidence_first
# [882/1500] article_id=171184 | prompt_3_conservative
# [883/1500] article_id=206722 | prompt_1_basic
# [884/1500] article_id=206722 | prompt_2_evidence_first
# [885/1500] article_id=206722 | prompt_3_conservative
# [886/1500] article_id=35803 | prompt_1_basic
# [887/1500] article_id=35803 | prompt_2_evidence_first
# [888/1500] article_id=35803 | prompt_3_conservative
# [889/1500] article_id=176730 | prompt_1_basic
# [890/1500] article_id=176730 | prompt_2_evidence_first
# [891/1500] article_id=176730 | prompt_3_conservative
# [892/1500] article_id=153896 | prompt_1_basic
# [893/1500] article_id=153896 | prompt_2_evidence_first
# [894/1500] article_id=153896 | prompt_3_conservative
# [895/1500] article_id=4666 | prompt_1_basic
# [896/1500] article_id=4666 | prompt_2_evidence_first
# [897/1500] article_id=4666 | prompt_3_conservative
# [898/1500] article_id=176191 | prompt_1_basic
# [899/1500] article_id=176191 | prompt_2_evidence_first
# [900/1500] article_id=176191 | prompt_3_conservative
# [901/1500] article_id=41271 | prompt_1_basic
# [902/1500] article_id=41271 | prompt_2_evidence_first
# [903/1500] article_id=41271 | prompt_3_conservative
# [904/1500] article_id=58550 | prompt_1_basic
# [905/1500] article_id=58550 | prompt_2_evidence_first
# [906/1500] article_id=58550 | prompt_3_conservative
# [907/1500] article_id=12987 | prompt_1_basic
# [908/1500] article_id=12987 | prompt_2_evidence_first
# [909/1500] article_id=12987 | prompt_3_conservative
# [910/1500] article_id=65535 | prompt_1_basic
# [911/1500] article_id=65535 | prompt_2_evidence_first
# [912/1500] article_id=65535 | prompt_3_conservative
# [913/1500] article_id=132049 | prompt_1_basic
# [914/1500] article_id=132049 | prompt_2_evidence_first
# [915/1500] article_id=132049 | prompt_3_conservative
# [916/1500] article_id=23783 | prompt_1_basic
# [917/1500] article_id=23783 | prompt_2_evidence_first
# [918/1500] article_id=23783 | prompt_3_conservative
# [919/1500] article_id=29682 | prompt_1_basic
# [920/1500] article_id=29682 | prompt_2_evidence_first
# [921/1500] article_id=29682 | prompt_3_conservative
# [922/1500] article_id=73771 | prompt_1_basic
# [923/1500] article_id=73771 | prompt_2_evidence_first
# [924/1500] article_id=73771 | prompt_3_conservative
# [925/1500] article_id=260521 | prompt_1_basic
# [926/1500] article_id=260521 | prompt_2_evidence_first
# [927/1500] article_id=260521 | prompt_3_conservative
# [928/1500] article_id=72258 | prompt_1_basic
# [929/1500] article_id=72258 | prompt_2_evidence_first
# [930/1500] article_id=72258 | prompt_3_conservative
# [931/1500] article_id=59893 | prompt_1_basic
# [932/1500] article_id=59893 | prompt_2_evidence_first
# [933/1500] article_id=59893 | prompt_3_conservative
# [934/1500] article_id=164535 | prompt_1_basic
# [935/1500] article_id=164535 | prompt_2_evidence_first
# [936/1500] article_id=164535 | prompt_3_conservative
# [937/1500] article_id=206218 | prompt_1_basic
# [938/1500] article_id=206218 | prompt_2_evidence_first
# [939/1500] article_id=206218 | prompt_3_conservative
# [940/1500] article_id=18116 | prompt_1_basic
# [941/1500] article_id=18116 | prompt_2_evidence_first
# [942/1500] article_id=18116 | prompt_3_conservative
# [943/1500] article_id=65185 | prompt_1_basic
# [944/1500] article_id=65185 | prompt_2_evidence_first
# ...
# [1425/1500] article_id=78648 | prompt_3_conservative
# [1426/1500] article_id=178090 | prompt_1_basic
# [1427/1500] article_id=178090 | prompt_2_evidence_first
# [1428/1500] article_id=178090 | prompt_3_conservative
# [1429/1500] article_id=188805 | prompt_1_basic
# [1430/1500] article_id=188805 | prompt_2_evidence_first
# [1431/1500] article_id=188805 | prompt_3_conservative
# [1432/1500] article_id=129389 | prompt_1_basic
# [1433/1500] article_id=129389 | prompt_2_evidence_first
# [1434/1500] article_id=129389 | prompt_3_conservative
# [1435/1500] article_id=153246 | prompt_1_basic
# [1436/1500] article_id=153246 | prompt_2_evidence_first
# [1437/1500] article_id=153246 | prompt_3_conservative
# [1438/1500] article_id=48594 | prompt_1_basic
# [1439/1500] article_id=48594 | prompt_2_evidence_first
# [1440/1500] article_id=48594 | prompt_3_conservative
# [1441/1500] article_id=59123 | prompt_1_basic
# [1442/1500] article_id=59123 | prompt_2_evidence_first
# [1443/1500] article_id=59123 | prompt_3_conservative
# [1444/1500] article_id=162004 | prompt_1_basic
# [1445/1500] article_id=162004 | prompt_2_evidence_first
# [1446/1500] article_id=162004 | prompt_3_conservative
# [1447/1500] article_id=154406 | prompt_1_basic
# [1448/1500] article_id=154406 | prompt_2_evidence_first
# [1449/1500] article_id=154406 | prompt_3_conservative
# [1450/1500] article_id=70329 | prompt_1_basic
# [1451/1500] article_id=70329 | prompt_2_evidence_first
# [1452/1500] article_id=70329 | prompt_3_conservative
# [1453/1500] article_id=43299 | prompt_1_basic
# [1454/1500] article_id=43299 | prompt_2_evidence_first
# [1455/1500] article_id=43299 | prompt_3_conservative
# [1456/1500] article_id=64392 | prompt_1_basic
# [1457/1500] article_id=64392 | prompt_2_evidence_first
# [1458/1500] article_id=64392 | prompt_3_conservative
# [1459/1500] article_id=46527 | prompt_1_basic
# [1460/1500] article_id=46527 | prompt_2_evidence_first
# [1461/1500] article_id=46527 | prompt_3_conservative
# [1462/1500] article_id=169300 | prompt_1_basic
# [1463/1500] article_id=169300 | prompt_2_evidence_first
# [1464/1500] article_id=169300 | prompt_3_conservative
# [1465/1500] article_id=190967 | prompt_1_basic
# [1466/1500] article_id=190967 | prompt_2_evidence_first
# [1467/1500] article_id=190967 | prompt_3_conservative
# [1468/1500] article_id=235870 | prompt_1_basic
# [1469/1500] article_id=235870 | prompt_2_evidence_first
# [1470/1500] article_id=235870 | prompt_3_conservative
# [1471/1500] article_id=10803 | prompt_1_basic
# [1472/1500] article_id=10803 | prompt_2_evidence_first
# [1473/1500] article_id=10803 | prompt_3_conservative
# [1474/1500] article_id=135856 | prompt_1_basic
# [1475/1500] article_id=135856 | prompt_2_evidence_first
# [1476/1500] article_id=135856 | prompt_3_conservative
# [1477/1500] article_id=74495 | prompt_1_basic
# [1478/1500] article_id=74495 | prompt_2_evidence_first
# [1479/1500] article_id=74495 | prompt_3_conservative
# [1480/1500] article_id=191457 | prompt_1_basic
# [1481/1500] article_id=191457 | prompt_2_evidence_first
# [1482/1500] article_id=191457 | prompt_3_conservative
# [1483/1500] article_id=33274 | prompt_1_basic
# [1484/1500] article_id=33274 | prompt_2_evidence_first
# [1485/1500] article_id=33274 | prompt_3_conservative
# [1486/1500] article_id=67104 | prompt_1_basic
# [1487/1500] article_id=67104 | prompt_2_evidence_first
# [1488/1500] article_id=67104 | prompt_3_conservative
# [1489/1500] article_id=204217 | prompt_1_basic
# [1490/1500] article_id=204217 | prompt_2_evidence_first
# [1491/1500] article_id=204217 | prompt_3_conservative
# [1492/1500] article_id=128725 | prompt_1_basic
# [1493/1500] article_id=128725 | prompt_2_evidence_first
# [1494/1500] article_id=128725 | prompt_3_conservative
# [1495/1500] article_id=67859 | prompt_1_basic
# [1496/1500] article_id=67859 | prompt_2_evidence_first
# [1497/1500] article_id=67859 | prompt_3_conservative
# [1498/1500] article_id=237046 | prompt_1_basic
# [1499/1500] article_id=237046 | prompt_2_evidence_first
# [1500/1500] article_id=237046 | prompt_3_conservative
#
# Batch završen. Novi pozivi: 1500, preskočeno zbog RESUME: 0
# Raw JSONL: openrouter_prompt_tests\raw_prompt_outputs.jsonl
#
# Output fajlovi:
# Flat CSV: openrouter_prompt_tests\flat_prompt_results.csv
# Agreement summary CSV: openrouter_prompt_tests\prompt_agreement_summary.csv
# Final majority labels CSV: openrouter_prompt_tests\final_majority_labels.csv
#
# Valid JSON po promptu:
# prompt_name
# prompt_1_basic             1.0
# prompt_2_evidence_first    1.0
# prompt_3_conservative      1.0
# Name: valid_json, dtype: float64
# Relevant count po promptu:
# prompt_name
# prompt_1_basic             304
# prompt_2_evidence_first    225
# prompt_3_conservative      149
# Name: is_relevant, dtype: int64
#   article_id              prompt_name  valid_json error  \
# 0     124893           prompt_1_basic        True
# 1     124893  prompt_2_evidence_first        True
# 2     124893    prompt_3_conservative        True
# 3     182281           prompt_1_basic        True
# 4     182281  prompt_2_evidence_first        True
#
#                                         raw_response portal       datum  \
# 0  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 1  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 2  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 3  {\n  "article_id": "182281",\n  "is_relevant":...   RTRS  2021-11-13
# 4  {\n  "article_id": "182281",\n  "is_relevant":...   RTRS  2021-11-13
#
#                                               naslov  \
# 0  Državljanin Srbije među zaraženim članovima po...
# 1  Državljanin Srbije među zaraženim članovima po...
# 2  Državljanin Srbije među zaraženim članovima po...
# 3  "Vašington upozoren da ne podržava nezavisnost...
# 4  "Vašington upozoren da ne podržava nezavisnost...
#
#                  tema_sampling  is_relevant  ...  \
# 0    euroatlantske_integracije        False  ...
# 1    euroatlantske_integracije        False  ...
# 2    euroatlantske_integracije        False  ...
# 3  gradjanska_vs_konstitutivni        False  ...
# 4  gradjanska_vs_konstitutivni        False  ...
#
#   negiranje_genocida_confidence  negiranje_genocida_evidence  \
# 0                          0.99                           []
# 1                          0.00                           []
# 2                          0.00                           []
# 3                          0.99                           []
# 4                          0.00                           []
#
#    gradjanska_vs_konstitutivni_mentioned  gradjanska_vs_konstitutivni_stance  \
# 0                                  False                                   0
# 1                                  False                                   0
# 2                                  False                                   0
# 3                                  False                                   0
# 4                                  False                                   0
#
#   gradjanska_vs_konstitutivni_confidence  \
# 0                                   0.99
# 1                                   0.00
# 2                                   0.00
# 3                                   0.99
# 4                                   0.00
#
#    gradjanska_vs_konstitutivni_evidence  izborna_reforma_mentioned  \
# 0                                    []                      False
# 1                                    []                      False
# 2                                    []                      False
# 3                                    []                      False
# 4                                    []                      False
#
#    izborna_reforma_stance izborna_reforma_confidence  izborna_reforma_evidence
# 0                       0                       0.99                        []
# 1                       0                       0.00                        []
# 2                       0                       0.00                        []
# 3                       0                       0.99                        []
# 4                       0                       0.00                        []
#
# [5 rows x 27 columns]
#   article_id   portal       datum  \
# 0      10130  Klix.ba  2022-10-08
# 1     103671     6yka  2020-11-15
# 2      10803  Klix.ba  2022-09-19
# 3     109692     6yka  2022-10-05
# 4      11068  Klix.ba  2022-09-11
#
#                                               naslov    tema_sampling  \
# 0  Schmidt opet odbio reći da li je sa Hrvatskom ...  izborna_reforma
# 1                   DNS se povukao s izbora u Doboju  izborna_reforma
# 2  Gorica Dodik usporedila svog oca sa Ivom Andri...  izborna_reforma
# 3  “Batinaši” u Doboju u izbornoj noći tokom broj...  izborna_reforma
# 4  CIK BiH edukativnim videosnimkom objašnjava ka...  izborna_reforma
#
#   is_relevant_values  is_relevant_agree  primary_topic_values  \
# 0               True               True       izborna_reforma
# 1         True|False              False  izborna_reforma|none
# 2              False               True                  none
# 3         True|False              False  izborna_reforma|none
# 4         True|False              False  izborna_reforma|none
#
#    primary_topic_agree euroatlantske_integracije_mentioned_values  ...  \
# 0                 True                                      False  ...
# 1                False                                      False  ...
# 2                 True                                      False  ...
# 3                False                                      False  ...
# 4                False                                      False  ...
#
#    negiranje_genocida_stance_values negiranje_genocida_stance_agree  \
# 0                                 0                            True
# 1                                 0                            True
# 2                                 0                            True
# 3                                 0                            True
# 4                                 0                            True
#
#    gradjanska_vs_konstitutivni_mentioned_values  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   gradjanska_vs_konstitutivni_mentioned_agree  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#    gradjanska_vs_konstitutivni_stance_values  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#   gradjanska_vs_konstitutivni_stance_agree  izborna_reforma_mentioned_values  \
# 0                                     True                              True
# 1                                     True                        True|False
# 2                                     True                             False
# 3                                     True                        True|False
# 4                                     True                        True|False
#
#   izborna_reforma_mentioned_agree  izborna_reforma_stance_values  \
# 0                            True                              0
# 1                           False                              0
# 2                            True                              0
# 3                           False                              0
# 4                           False                              0
#
#   izborna_reforma_stance_agree
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                         True
#
# [5 rows x 25 columns]
#   article_id   portal       datum  \
# 0      10130  Klix.ba  2022-10-08
# 1     103671     6yka  2020-11-15
# 2      10803  Klix.ba  2022-09-19
# 3     109692     6yka  2022-10-05
# 4      11068  Klix.ba  2022-09-11
#
#                                               naslov    tema_sampling  \
# 0  Schmidt opet odbio reći da li je sa Hrvatskom ...  izborna_reforma
# 1                   DNS se povukao s izbora u Doboju  izborna_reforma
# 2  Gorica Dodik usporedila svog oca sa Ivom Andri...  izborna_reforma
# 3  “Batinaši” u Doboju u izbornoj noći tokom broj...  izborna_reforma
# 4  CIK BiH edukativnim videosnimkom objašnjava ka...  izborna_reforma
#
#    is_relevant_final primary_topic_final  n_prompts  n_valid_json  \
# 0               True     izborna_reforma          3             3
# 1              False                none          3             3
# 2              False                none          3             3
# 3              False                none          3             3
# 4              False                none          3             3
#
#    euroatlantske_integracije_mentioned_final  ...  \
# 0                                      False  ...
# 1                                      False  ...
# 2                                      False  ...
# 3                                      False  ...
# 4                                      False  ...
#
#    euroatlantske_integracije_confidence_mean  \
# 0                                   0.316667
# 1                                   0.330000
# 2                                   0.330000
# 3                                   0.330000
# 4                                   0.316667
#
#    negiranje_genocida_mentioned_final  negiranje_genocida_stance_final  \
# 0                               False                                0
# 1                               False                                0
# 2                               False                                0
# 3                               False                                0
# 4                               False                                0
#
#    negiranje_genocida_confidence_mean  \
# 0                            0.316667
# 1                            0.330000
# 2                            0.330000
# 3                            0.330000
# 4                            0.316667
#
#    gradjanska_vs_konstitutivni_mentioned_final  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    gradjanska_vs_konstitutivni_stance_final  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    gradjanska_vs_konstitutivni_confidence_mean  \
# 0                                     0.316667
# 1                                     0.330000
# 2                                     0.330000
# 3                                     0.330000
# 4                                     0.316667
#
#    izborna_reforma_mentioned_final  izborna_reforma_stance_final  \
# 0                             True                             0
# 1                            False                             0
# 2                            False                             0
# 3                            False                             0
# 4                            False                             0
#
#    izborna_reforma_confidence_mean
# 0                         0.900000
# 1                         0.283333
# 2                         0.330000
# 3                         0.283333
# 4                         0.300000
#
# [5 rows x 21 columns]

# %%
flat_df
# Out:
#      article_id              prompt_name  valid_json error  \
# 0        124893           prompt_1_basic        True
# 1        124893  prompt_2_evidence_first        True
# 2        124893    prompt_3_conservative        True
# 3        182281           prompt_1_basic        True
# 4        182281  prompt_2_evidence_first        True
# ...         ...                      ...         ...   ...
# 1495      67859  prompt_2_evidence_first        True
# 1496      67859    prompt_3_conservative        True
# 1497     237046           prompt_1_basic        True
# 1498     237046  prompt_2_evidence_first        True
# 1499     237046    prompt_3_conservative        True
#
#                                            raw_response          portal  \
# 0     {\n  "article_id": "124893",\n  "is_relevant":...            RTRS
# 1     {\n  "article_id": "124893",\n  "is_relevant":...            RTRS
# 2     {\n  "article_id": "124893",\n  "is_relevant":...            RTRS
# 3     {\n  "article_id": "182281",\n  "is_relevant":...            RTRS
# 4     {\n  "article_id": "182281",\n  "is_relevant":...            RTRS
# ...                                                 ...             ...
# 1495  {\n  "article_id": "67859",\n  "is_relevant": ...         Klix.ba
# 1496  {\n  "article_id": "67859",\n  "is_relevant": ...         Klix.ba
# 1497  {\n  "article_id": "237046",\n  "is_relevant":...  Radio Sarajevo
# 1498  {\n  "article_id": "237046",\n  "is_relevant":...  Radio Sarajevo
# 1499  {\n  "article_id": "237046",\n  "is_relevant":...  Radio Sarajevo
#
#            datum                                             naslov  \
# 0     2020-03-07  Državljanin Srbije među zaraženim članovima po...
# 1     2020-03-07  Državljanin Srbije među zaraženim članovima po...
# 2     2020-03-07  Državljanin Srbije među zaraženim članovima po...
# 3     2021-11-13  "Vašington upozoren da ne podržava nezavisnost...
# 4     2021-11-13  "Vašington upozoren da ne podržava nezavisnost...
# ...          ...                                                ...
# 1495  2024-05-15  Vučić i Dodik dogovorili: Srpski sabor će biti...
# 1496  2024-05-15  Vučić i Dodik dogovorili: Srpski sabor će biti...
# 1497  2024-05-23  Sead Turčalo komentirao poteze Milorada Dodika...
# 1498  2024-05-23  Sead Turčalo komentirao poteze Milorada Dodika...
# 1499  2024-05-23  Sead Turčalo komentirao poteze Milorada Dodika...
#
#                     tema_sampling  is_relevant  ...  \
# 0       euroatlantske_integracije        False  ...
# 1       euroatlantske_integracije        False  ...
# 2       euroatlantske_integracije        False  ...
# 3     gradjanska_vs_konstitutivni        False  ...
# 4     gradjanska_vs_konstitutivni        False  ...
# ...                           ...          ...  ...
# 1495           negiranje_genocida         True  ...
# 1496           negiranje_genocida         True  ...
# 1497           negiranje_genocida         True  ...
# 1498           negiranje_genocida         True  ...
# 1499           negiranje_genocida        False  ...
#
#      negiranje_genocida_confidence  \
# 0                             0.99
# 1                             0.00
# 2                             0.00
# 3                             0.99
# 4                             0.00
# ...                            ...
# 1495                          0.90
# 1496                          0.90
# 1497                          0.90
# 1498                          0.90
# 1499                          0.00
#
#                             negiranje_genocida_evidence  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1495  ["rezoluciji o genocidu u Srebrenici", "najtež...
# 1496  ["članak se bavi rezolucijom o genocidu u Sreb...
# 1497  ["Naslov članka povezuje Milorada Dodika sa Ra...
# 1498  ["Sead Turčalo komentirao poteze Milorada Dodi...
# 1499                                                 []
#
#       gradjanska_vs_konstitutivni_mentioned  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 1495                                  False
# 1496                                  False
# 1497                                  False
# 1498                                  False
# 1499                                  False
#
#       gradjanska_vs_konstitutivni_stance  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ...                                  ...
# 1495                                   0
# 1496                                   0
# 1497                                   0
# 1498                                   0
# 1499                                   0
#
#      gradjanska_vs_konstitutivni_confidence  \
# 0                                      0.99
# 1                                      0.00
# 2                                      0.00
# 3                                      0.99
# 4                                      0.00
# ...                                     ...
# 1495                                   0.00
# 1496                                   0.00
# 1497                                   0.95
# 1498                                   0.00
# 1499                                   0.00
#
#       gradjanska_vs_konstitutivni_evidence  izborna_reforma_mentioned  \
# 0                                       []                      False
# 1                                       []                      False
# 2                                       []                      False
# 3                                       []                      False
# 4                                       []                      False
# ...                                    ...                        ...
# 1495                                    []                      False
# 1496                                    []                      False
# 1497                                    []                      False
# 1498                                    []                      False
# 1499                                    []                      False
#
#       izborna_reforma_stance izborna_reforma_confidence  \
# 0                          0                       0.99
# 1                          0                       0.00
# 2                          0                       0.00
# 3                          0                       0.99
# 4                          0                       0.00
# ...                      ...                        ...
# 1495                       0                       0.00
# 1496                       0                       0.00
# 1497                       0                       0.95
# 1498                       0                       0.00
# 1499                       0                       0.00
#
#       izborna_reforma_evidence
# 0                           []
# 1                           []
# 2                           []
# 3                           []
# 4                           []
# ...                        ...
# 1495                        []
# 1496                        []
# 1497                        []
# 1498                        []
# 1499                        []
#
# [1500 rows x 27 columns]

# %%
article_text_cols = df[["article_id", "SADRZAJ"]].copy()
article_text_cols["article_id"] = article_text_cols["article_id"].astype(str)

flat_df["article_id"] = flat_df["article_id"].astype(str)

flat_df = flat_df.merge(
    article_text_cols,
    on="article_id",
    how="left"
)

display(flat_df.head())
# Out:
#   article_id              prompt_name  valid_json error  \
# 0     124893           prompt_1_basic        True
# 1     124893  prompt_2_evidence_first        True
# 2     124893    prompt_3_conservative        True
# 3     182281           prompt_1_basic        True
# 4     182281  prompt_2_evidence_first        True
#
#                                         raw_response portal       datum  \
# 0  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 1  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 2  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 3  {\n  "article_id": "182281",\n  "is_relevant":...   RTRS  2021-11-13
# 4  {\n  "article_id": "182281",\n  "is_relevant":...   RTRS  2021-11-13
#
#                                               naslov  \
# 0  Državljanin Srbije među zaraženim članovima po...
# 1  Državljanin Srbije među zaraženim članovima po...
# 2  Državljanin Srbije među zaraženim članovima po...
# 3  "Vašington upozoren da ne podržava nezavisnost...
# 4  "Vašington upozoren da ne podržava nezavisnost...
#
#                  tema_sampling  is_relevant  ... negiranje_genocida_evidence  \
# 0    euroatlantske_integracije        False  ...                          []
# 1    euroatlantske_integracije        False  ...                          []
# 2    euroatlantske_integracije        False  ...                          []
# 3  gradjanska_vs_konstitutivni        False  ...                          []
# 4  gradjanska_vs_konstitutivni        False  ...                          []
#
#    gradjanska_vs_konstitutivni_mentioned  gradjanska_vs_konstitutivni_stance  \
# 0                                  False                                   0
# 1                                  False                                   0
# 2                                  False                                   0
# 3                                  False                                   0
# 4                                  False                                   0
#
#    gradjanska_vs_konstitutivni_confidence  \
# 0                                    0.99
# 1                                    0.00
# 2                                    0.00
# 3                                    0.99
# 4                                    0.00
#
#   gradjanska_vs_konstitutivni_evidence  izborna_reforma_mentioned  \
# 0                                   []                      False
# 1                                   []                      False
# 2                                   []                      False
# 3                                   []                      False
# 4                                   []                      False
#
#    izborna_reforma_stance  izborna_reforma_confidence  \
# 0                       0                        0.99
# 1                       0                        0.00
# 2                       0                        0.00
# 3                       0                        0.99
# 4                       0                        0.00
#
#   izborna_reforma_evidence                                            SADRZAJ
# 0                       []  Od evropskih zemalja, najteže je pogođena Ital...
# 1                       []  Od evropskih zemalja, najteže je pogođena Ital...
# 2                       []  Od evropskih zemalja, najteže je pogođena Ital...
# 3                       []  Vang je naglasio da Vašington treba da ispuni ...
# 4                       []  Vang je naglasio da Vašington treba da ispuni ...
#
# [5 rows x 28 columns]

# %%
# Premjesti kolonu sadrzaj da bude druga kolona po redu

col = "sadrzaj" if "sadrzaj" in flat_df.columns else "SADRZAJ"

cols = flat_df.columns.tolist()
cols.insert(1, cols.pop(cols.index(col)))

flat_df = flat_df[cols]

display(flat_df.head())
# Out:
#   article_id                                            SADRZAJ  \
# 0     124893  Od evropskih zemalja, najteže je pogođena Ital...
# 1     124893  Od evropskih zemalja, najteže je pogođena Ital...
# 2     124893  Od evropskih zemalja, najteže je pogođena Ital...
# 3     182281  Vang je naglasio da Vašington treba da ispuni ...
# 4     182281  Vang je naglasio da Vašington treba da ispuni ...
#
#                prompt_name  valid_json error  \
# 0           prompt_1_basic        True
# 1  prompt_2_evidence_first        True
# 2    prompt_3_conservative        True
# 3           prompt_1_basic        True
# 4  prompt_2_evidence_first        True
#
#                                         raw_response portal       datum  \
# 0  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 1  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 2  {\n  "article_id": "124893",\n  "is_relevant":...   RTRS  2020-03-07
# 3  {\n  "article_id": "182281",\n  "is_relevant":...   RTRS  2021-11-13
# 4  {\n  "article_id": "182281",\n  "is_relevant":...   RTRS  2021-11-13
#
#                                               naslov  \
# 0  Državljanin Srbije među zaraženim članovima po...
# 1  Državljanin Srbije među zaraženim članovima po...
# 2  Državljanin Srbije među zaraženim članovima po...
# 3  "Vašington upozoren da ne podržava nezavisnost...
# 4  "Vašington upozoren da ne podržava nezavisnost...
#
#                  tema_sampling  ...  negiranje_genocida_confidence  \
# 0    euroatlantske_integracije  ...                           0.99
# 1    euroatlantske_integracije  ...                           0.00
# 2    euroatlantske_integracije  ...                           0.00
# 3  gradjanska_vs_konstitutivni  ...                           0.99
# 4  gradjanska_vs_konstitutivni  ...                           0.00
#
#   negiranje_genocida_evidence  gradjanska_vs_konstitutivni_mentioned  \
# 0                          []                                  False
# 1                          []                                  False
# 2                          []                                  False
# 3                          []                                  False
# 4                          []                                  False
#
#    gradjanska_vs_konstitutivni_stance  gradjanska_vs_konstitutivni_confidence  \
# 0                                   0                                    0.99
# 1                                   0                                    0.00
# 2                                   0                                    0.00
# 3                                   0                                    0.99
# 4                                   0                                    0.00
#
#   gradjanska_vs_konstitutivni_evidence  izborna_reforma_mentioned  \
# 0                                   []                      False
# 1                                   []                      False
# 2                                   []                      False
# 3                                   []                      False
# 4                                   []                      False
#
#    izborna_reforma_stance  izborna_reforma_confidence izborna_reforma_evidence
# 0                       0                        0.99                       []
# 1                       0                        0.00                       []
# 2                       0                        0.00                       []
# 3                       0                        0.99                       []
# 4                       0                        0.00                       []
#
# [5 rows x 28 columns]

# %%
flat_df.to_csv("zaasju.csv", index=False, encoding="utf-8-sig")
